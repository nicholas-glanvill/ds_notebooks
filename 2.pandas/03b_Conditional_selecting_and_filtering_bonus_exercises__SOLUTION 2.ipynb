# %%
import pandas as pd

# %% [markdown]
# Read the csv file from this url:
# 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
#
# Name it `sets_df`

# %%
# Your code here
url = 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
sets_df = pd.read_csv(path)

# %% [markdown]
# #### Exercise 1.
# Find and display all sets from the year 2005.

# %%
# Your code here
year_mask = sets_df['year'] == 2005

sets_df.loc[year_mask,:]

# %% [markdown]
# #### Exercise 2
# Find and display sets from year 2010 with more than 500 parts.

# %%
# Your code here
year_mask = sets_df['year'] == 2010
parts_mask = sets_df['num_parts'] > 500

sets_df.loc[year_mask & parts_mask,:]
# Out:
#      set_num                                     name  year  theme_id  \
# 723   8098-1                         Clone Turbo Tank  2010       165
# 744  10155-1  Maersk Line Container Ship 2010 Edition  2010       276
#
#      num_parts
# 723       1142
# 744        984

# %% [markdown]
# #### Exercise 3
# Find and display sets having between 100 and 200 parts by using `.between()`.

# %%
# Your code here
sets_df.loc[sets_df['num_parts'].between(100,200),:]
# Out:
#      set_num                        name  year  theme_id  num_parts
# 3     6593-1               Blaze Battler  1991        74        126
# 21    6043-1             Dragon Defender  1993       186        156
# 35   76039-1        Ant-Man Final Battle  2015       493        194
# 39   10584-1                Forest: Park  2015       504        105
# 50    7092-1  Skeletons' Prison Carriage  2007       193        193
# ..       ...                         ...   ...       ...        ...
# 947    918-2            21 8-Stud Bricks  1969       371        126
# 971  70128-1      Braptor's Wing Striker  2014       571        145
# 972   6369-1                      Garage  1985        85        134
# 991   4478-2  Geonosian Fighter Blue Box  2004       167        153
# 993   9491-1            Geonosian Cannon  2012       165        133
#
# [122 rows x 5 columns]

# %% [markdown]
# #### Exercise 4
# Find and display sets that are **not** from the year 2002.

# %%
# Your code here
not_year_mask = sets_df['year'] != 2012

sets_df.loc[not_year_mask,:]
# Out:
#           set_num                                               name  year  \
# 0    TRUFRIENDS-1                                       Wishing Well  2017
# 1          7958-8  Advent Calendar 2011 Star Wars (Day  7) - Tool...  2011
# 2        71005-15                                       Chief Wiggum  2014
# 3          6593-1                                      Blaze Battler  1991
# 4         75916-1                               Dilophosaurus Ambush  2015
# ..            ...                                                ...   ...
# 992       65579-1  Knights' Kingdom Value Pack 8770 and 8771 with...  2004
# 994        7979-5  Advent Calendar 2008 Castle  (Day 4) - White S...  2008
# 995        1668-1                      Basic Building Set Trial Size  1992
# 996       71237-1                        Aquaman and Aqua Watercraft  2016
# 998        5161-1                              Inverted Slope Bricks  1987
#
#      theme_id  num_parts
# 0         494         33
# ...

# %% [markdown]
# #### Exercise 5
# Display all sets with `theme_id` 158

# %%
# Your code here
theme_mask = sets_df['theme_id'] == 158

sets_df.loc[theme_mask,:]
# Out:
#         set_num                         name  year  theme_id  num_parts
# 128     75174-1          Desert Skiff Escape  2017       158        284
# 238     75531-1      Stormtrooper" Commander  2017       158        100
# 252     75104-1  Kylo Ren’s Command Shuttle™  2015       158       1002
# 448  SW911725-1                  Sandcrawler  2017       158         50
# 612     75105-1           Millennium Falcon™  2015       158       1328
# 673     75035-1            Kashyyyk Troopers  2014       158         99
# 746     75178-1             Jakku Quadjumper  2017       158        456
# 877   2853835-1       White Boba Fett Figure  2010       158          5

# %% [markdown]
# #### Exercise 5
# Find and display the 10 biggest sets (by number of parts) by using `.nlargest()`.

# %%
# Your code here
sets_df.nlargest(10,'num_parts')
# Out:
#      set_num                     name  year  theme_id  num_parts
# 888  70810-1     MetalBeard’s Sea Cow  2014       578       2741
# 559  10251-1               Brick Bank  2016       155       2383
# 850  71042-1              Silent Mary  2017       263       2286
# 544  45120-1    LearnToLearn Core set  2014       528       2016
# 970   3598-1        XXL 2000 Canister  2005        37       2000
# 445   3723-1          Lego Minifigure  2000       276       1849
# 641   9609-1  Technology Resource Set  1995         1       1730
# 450  10937-1   Arkham Asylum Breakout  2012       484       1619
# 244  10193-1  Medieval Market Village  2009       193       1616
# 999  10223-1           Kingdoms Joust  2012       196       1574

# %% [markdown]
# #### Exercise 6
# Display only the names of all sets from the period 2000-2010.

# %%
# Your code here
period_mask = sets_df['year'].between(2000,2010)

sets_df.loc[period_mask,['name']]
# Out:
#                                                   name
# 5                                         Tipper Truck
# 9                                      Twin X-treme RC
# 10                         Golden Land Promo (Polybag)
# 12                               X-wing Fighter - Mini
# 13                                       TECHNIC Motor
# ..                                                 ...
# 982  Advent Calendar 2008 City (Day 13) Diver and S...
# 987                                   Fire Nation Ship
# 991                         Geonosian Fighter Blue Box
# 992  Knights' Kingdom Value Pack 8770 and 8771 with...
# 994  Advent Calendar 2008 Castle  (Day 4) - White S...
#
# [342 rows x 1 columns]

# %% [markdown]
# #### Exercise 7
# How many sets are from the period 2005-2010?

# %%
# Your code here
period_mask = sets_df['year'].between(2005,2010)

sets_df.loc[period_mask,:].shape[0]
# Out:
# 188

# %% [markdown]
# #### Exercise 8
# Show all sets that have set_num in the `set_num_list` provided below. Use `.isin()`.

# %%
set_num_list = ['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11']

# %%
# Your code here
sets_df.loc[sets_df['set_num'].isin(set_num_list),:]
# Out:
#       set_num                                               name  year  \
# 842    2250-2                Advent Calendar 2000 (Day  1) Plane  2000
# 859   7324-21  Advent Calendar 2005 City (Day 20) Skateboard ...  2005
# 886   9509-15  Advent Calendar 2012, Star Wars (Day 14) - Gen...  2012
# 900    2824-8    Advent Calendar 2010 City (Day 7) Piano / Organ  2010
# 926   7324-12       Advent Calendar 2005 City (Day 11) Barricade  2005
# 945  60024-11                Advent Calendar 2013, City (Day 10)  2013
#
#      theme_id  num_parts
# 842       217         12
# 859       220          4
# 886       225         10
# 900       220         10
# 926       220          9
# 945       220          8

# %% [markdown]
# #### Exercise 9
# Find the 5 smallest sets from the 1990's.

# %%
# Your code here
year_mask = sets_df['year'].between(1990,1999)
sets_df.loc[year_mask,:].nsmallest(5,'num_parts')
# Out:
#             set_num                                               name  year  \
# 709          9646-1                      Wheel and Axle Classroom Pack  1994
# 237  tech007promo-1  Technic Figure Cyber Person Promotional Polyba...  1998
# 876          4519-1                                      Rail Crossing  1999
# 142          9248-1                              Bonus Lego Basic Town  1998
# 879          5304-1                                          Wheelsets  1992
#
#      theme_id  num_parts
# 709       529          0
# 237         3          1
# 876       244          1
# 142       534          2
# 879       456          2

# %%
# HINT:
# mask = _______.between(______, ________)
# _____.loc[____].n___est()

# %% [markdown]
# #### Exercise 10
# Find and display sets with more than 100 parts from the years 2010-2015.

# %%
# Your code here
parts_mask = sets_df['num_parts'] > 100
year_mask = sets_df['year'].between(2010, 2015)
sets_df.loc[parts_mask & year_mask]
# Out:
#      set_num                        name  year  theme_id  num_parts
# 4    75916-1        Dilophosaurus Ambush  2015       602        246
# 35   76039-1        Ant-Man Final Battle  2015       493        194
# 39   10584-1                Forest: Park  2015       504        105
# 58   70402-1          The Gatehouse Raid  2013       186        247
# 59   75022-1         Mandalorian Speeder  2013       170        210
# ..       ...                         ...   ...       ...        ...
# 960  79008-1          Pirate Ship Ambush  2013       569        754
# 971  70128-1      Braptor's Wing Striker  2014       571        145
# 984  70736-1  Attack of the Morro Dragon  2015       435        655
# 993   9491-1            Geonosian Cannon  2012       165        133
# 999  10223-1              Kingdoms Joust  2012       196       1574
#
# [107 rows x 5 columns]

# %% [markdown]
# ### Exercise 11
# Of the 10 largest sets, how many of them were released before the millennium? Use `.query()`.

# %%
# Your code here
sets_df.nlargest(10, 'num_parts').query('year < 2000').shape[0]
# Out:
# 1
