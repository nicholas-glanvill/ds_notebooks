# %%
import pandas as pd

# %% [markdown]
# Read the csv file from this url:
# 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
#
# Name it `sets_df`

# %%
# your code here
url = 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
sets_df = pd.read_csv(path)

# %% [markdown]
# ##### Hint

# %%
# url = ___________
# path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
# sets_df = pd.read_csv(_______)

# %% [markdown]
# #### Exercise 1
# Display the basic information about DataFrames `sets_df`  Check the number of rows, columns, data types, and non-null counts.

# %%
# your code here
sets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    1000 non-null   object
#  1   name       1000 non-null   object
#  2   year       1000 non-null   int64
#  3   theme_id   1000 non-null   int64
#  4   num_parts  1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# #### Exercise 2
# Show the first 5 rows of the DataFrame to get an initial idea about the data. Then show the first 7 instead.

# %%
# your code here
sets_df.head()
# Out:
#         set_num                                               name  year  \
# 0  TRUFRIENDS-1                                       Wishing Well  2017
# 1        7958-8  Advent Calendar 2011 Star Wars (Day  7) - Tool...  2011
# 2      71005-15                                       Chief Wiggum  2014
# 3        6593-1                                      Blaze Battler  1991
# 4       75916-1                               Dilophosaurus Ambush  2015
#
#    theme_id  num_parts
# 0       494         33
# 1       225          9
# 2       550          6
# 3        74        126
# 4       602        246

# %% [markdown]
# #### Exercise 3
# Display the summary statistics of the numerical columns in `sets_df`.

# %%
# your code here
sets_df.describe()
# Out:
#               year     theme_id    num_parts
# count  1000.000000  1000.000000  1000.000000
# mean   2002.080000   316.247000   155.721000
# std      13.650932   178.049194   289.391601
# min    1954.000000     1.000000     0.000000
# 25%    1997.000000   163.750000     8.000000
# 50%    2006.000000   333.500000    45.000000
# 75%    2013.000000   478.000000   171.250000
# max    2017.000000   616.000000  2741.000000

# %% [markdown]
# #### Exercise 4
# Print out a sentence that shows number of rows and columns.
# \
# Get the numbers of rows and columns using `.shape`.
# Save the number of columns in a variable `num_cols` and number of rows in a variable `num_rows`.
# Use those variables in your `print()` function.
#
# The sentence should look like this (the numbers should not be hardcoded - they need to come from the variables):
# **"This dataset has 1000 rows and 5 columns"**

# %%
# your code here
num_cols = sets_df.shape[1]
num_rows = sets_df.shape[0]

print(f"This dataset has {num_rows} rows and {num_cols} columns")
# Out:
# This dataset has 1000 rows and 5 columns

# %% [markdown]
# #### Exercise 5
# Select the column `year`

# %%
# your code here
sets_df['year']
# Out:
# 0      2017
# 1      2011
# 2      2014
# 3      1991
# 4      2015
#        ...
# 995    1992
# 996    2016
# 997    2012
# 998    1987
# 999    2012
# Name: year, Length: 1000, dtype: int64

# %% [markdown]
# #### Exercise 6
# Select all unique years from the column `year` using `.unique()`.

# %%
# your code here
sets_df['year'].unique()
# Out:
# array([2017, 2011, 2014, 1991, 2015, 2009, 1957, 1974, 1990, 2003, 2012,
#        2010, 1999, 1997, 2002, 2004, 1995, 1993, 1963, 1982, 1967, 2013,
#        1989, 2005, 1998, 1987, 1985, 2007, 1996, 2001, 2016, 1954, 1994,
#        1966, 2000, 2006, 2008, 1986, 1977, 1984, 1955, 1958, 1969, 1983,
#        1956, 1976, 1970, 1979, 1988, 1992, 1973, 1962, 1972, 1978, 1968,
#        1980, 1965, 1964, 1981, 1975, 1961, 1971])

# %% [markdown]
# #### Exercise 7
# Select the earliest year by using `.min()`

# %%
# your code here
sets_df['year'].min()
# Out:
# 1954

# %% [markdown]
# #### Exercise 8
# Select the latest year by using `.max()`

# %%
# your code here
sets_df['year'].max()
# Out:
# 2017

# %% [markdown]
# #### Exercise 9
# How many different themes are represented?

# %%
# your code here
sets_df['theme_id'].nunique()
# Out:
# 337

# %% [markdown]
# #### Exercise 10
# What's the largest number of pieces in one set? The smallest?

# %%
# your code here
sets_df['num_parts'].max()
sets_df['num_parts'].min()
# Out:
# 0

# %% [markdown]
# #### Exercise 11
# Select 10 random entries from the DataFrame.

# %%
# your code here
sets_df.sample(10)
# Out:
#          set_num                                               name  year  \
# 599        810-3                                     Gear Truck Set  1974
# 847        602-1                                   Fire Chief's Car  1978
# 224       5045-1                            Magnets, Magnet Holders  1991
# 606       3743-1                             Locomotive Blue Bricks  2001
# 443     852950-1                                    Alien Key Chain  2010
# 843       7699-1                       MT-101 Armored Drilling Unit  2007
# 46   cokejpiii-1  Japanese Coca-Cola Studios Polybag Collection ...  2001
# 152       1248-2                           Painted Trees and Bushes  1955
# 238      75531-1                            Stormtrooper" Commander  2017
# 851       7746-1                                 Single-Drum Roller  2009
#
#      theme_id  num_parts
# 599       472        110
# 847        74         24
# 224       443         12
# 606       238        106
# 443       503          0
# 843       137        634
# 46        273         24
# 152       371          6
# 238       158        100
# 851        56        207

# %% [markdown]
# #### Exercise 12
# What's the most common number of pieces in a set?

# %%
# your code here
sets_df['num_parts'].mode()
# Out:
# 0    0
# Name: num_parts, dtype: int64

# %% [markdown]
# #### Exercise 13
# Which five years have the most sets associated with them?

# %%
# your code here
sets_df['year'].value_counts().head()
# Out:
# year
# 2014    71
# 2015    66
# 2013    58
# 2012    46
# 2010    46
# Name: count, dtype: int64

# %% [markdown]
# #### Exercise 14
# Are all `set_num` values unique? Compare the number of unique `set_num` values to the number of rows in the DataFrame.

# %%
# your code here
sets_df['set_num'].nunique() == sets_df.shape[0]
# Out:
# True
