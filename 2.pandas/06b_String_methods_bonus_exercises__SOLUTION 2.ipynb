# %%
import pandas as pd

# %% [markdown]
# Read the csv file from this url:
# 'https://drive.google.com/file/d/1sXYEFFcJj0qlfqp08lPWaeuu_z35ICfp/view?usp=drive_link'
#
# Name it `sets_df`

# %%
# Your code here
url = 'https://drive.google.com/file/d/1sXYEFFcJj0qlfqp08lPWaeuu_z35ICfp/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
sets_df = pd.read_csv(path)

# %% [markdown]
# > Make sure you save the changes by overwriting the original DataFrame:
# e.g. `df['name'] = df['name'].str.upper()`

# %% [markdown]
# #### Exercise 1
# How long are the names? Does these value seem right?
# Look at a single name and see if you can figure out what is happening.

# %%
# Your code here
sets_df['name'].str.len()
# Out:
# 0      58
# 1      98
# 2      58
# 3      59
# 4      66
#        ..
# 995    75
# 996    73
# 997    59
# 998    67
# 999    60
# Name: name, Length: 1000, dtype: int64

# %%
sets_df.loc[0, 'name']
# Out:
# '                Wishing Well                              '

# %% [markdown]
# #### Exercise 2
# Remove the extra whiteshape from the `name` column.
# Check the length of the names again.

# %%
# Your code here
sets_df['name'] = sets_df['name'].str.strip()
sets_df['name'].str.len()
# Out:
# 0      12
# 1      52
# 2      12
# 3      13
# 4      20
#        ..
# 995    29
# 996    27
# 997    13
# 998    21
# 999    14
# Name: name, Length: 1000, dtype: int64

# %% [markdown]
# #### Exercise 3
# Change everything in the `name` column to lowercase.

# %%
# Your code here
sets_df['name'] = sets_df['name'].str.lower()
sets_df
# Out:
#                set_num                                               name  \
# 0    &&TRUFRIENDS-1**_                                       wishing well
# 1          &&7958-8**_  advent calendar 2011 star wars (day  7) - tool...
# 2        &&71005-15**_                                       chief wiggum
# 3          &&6593-1**_                                      blaze battler
# 4         &&75916-1**_                               dilophosaurus ambush
# ..                 ...                                                ...
# 995        &&1668-1**_                      basic building set trial size
# 996       &&71237-1**_                        aquaman and aqua watercraft
# 997        &&3939-1**_                                      mia's bedroom
# 998        &&5161-1**_                              inverted slope bricks
# 999       &&10223-1**_                                     kingdoms joust
#
#      year  theme_id  num_parts
# 0    2017       494         33
# 1    2011       225          9
# 2    2014       550          6
# 3    1991        74        126
# 4    2015       602        246
# ..    ...       ...        ...
# 995  1992       469         30
# 996  2016       604         43
# 997  2012       494         86
# 998  1987       443         16
# 999  2012       196       1574
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Exercise 4
# How many names contain the string 'lego'?
# Select those sets.

# %%
# Your code here
sets_df['name'].str.contains('lego').sum()
# Out:
# 55

# %%
sets_df.loc[sets_df['name'].str.contains('lego')]
# sets_df.query('name.str.contains("lego")')
# Out:
#                   set_num                                               name  \
# 6             &&200A-1**_                        lego town plan wooden board
# 19         &&4212838-1**_                  lego stores easter chick for 2004
# 54          &&LLCA51-1**_  legoland california 10th birthday cupcake box ...
# 71           &&71005-0**_  lego minifigures - the simpsons series [random...
# 77        &&DKCastle-1**_                lego brickmaster castle (hardcover)
# 90         &&2856195-1**_        lego minifigure ultimate sticker collection
# 109        &&Houston-2**_  lego store grand opening exclusive set, the ga...
# 131        &&5000249-1**_       lego® star wars™ boba fett™ minifigure clock
# 142           &&9248-1**_                              bonus lego basic town
# 149        &&5002423-1**_  lego® dc universe super heroes batman™ minifig...
# 155         &&71008-18**_            lego minifigures series 13 - sealed box
# 156          &&10565-1**_                     lego® duplo® creative suitcase
# 164         &&851003-1**_             lego® super heroes the joker key chain
# 216           &&1647-1**_                        lego motion 1b, turbo force
# 219         &&lmg003-1**_                                 lego japan ostrich
# 228        &&Houston-1**_  lego store grand opening exclusive set, baybro...
# 232         &&851331-1**_                    i love legoland magnet [female]
# 253        &&5002887-1**_                                     the lego® book
# 262         &&850998-1**_              lego® star wars™ boba fett™ key chain
# 264           &&6177-1**_                           lego basic bricks deluxe
# 303       &&Edmonton-1**_  lego store grand opening exclusive set, southg...
# 324          &&40086-1**_                                  lego easter bunny
# 329        &&5004868-1**_                              lego® mixels™ munchos
# 356        &&5004102-1**_               the lego® movie™ the essential guide
# 397      &&Wauwatosa-1**_  lego store grand opening exclusive set, mayfai...
# 399         &&850789-1**_                      lego® friends horse bag charm
# 403        &&5004251-1**_                     lego® friends olivia key light
# 426  &&FRNDSMAGBEACH-1**_  lego friends magazine issue 'friends on the be...
# 431         &&850598-1**_          lego® legends of chima™ game cards binder
# 445           &&3723-1**_                                    lego minifigure
# 505          &&71171-1**_      lego® dimensions™ playstation® 4 starter pack
# 550         &&853444-1**_                               lego® friends mirror
# 563           &&9797-1**_             lego mindstorms education nxt base set
# 573    &&Minneapolis-2**_  lego store grand re-opening exclusive set, mal...
# 574         &&llca12-1**_                     3d witch (legoland california)
# 578          &&71219-1**_                 lego® dimensions™ legolas fun pack
# 592           &&6137-1**_                    my first lego duplo supermarket
# 596        &&5004195-1**_  lego® star wars™: the visual dictionary (updat...
# 602         &&850896-1**_                 the lego® movie™ bad cop key chain
# 608        &&5003024-1**_  the lego® movie™ lucy/wyldstyle minifigure lin...
# 677        &&Sunrise-1**_  lego store grand opening exclusive set, sawgra...
# 682        &&5004549-1**_                            lego mixel collection 4
# 685        &&Glasgow-1**_  lego store grand opening exclusive set, glasgo...
# 692          &&66174-1**_                                lego firemen bundle
# 708         &&851015-1**_    lego® legends of chima™ scorpion sword & shield
# 747          &&K8761-1**_     the shadowed one (lego club members exclusive)
# 750         &&71007-18**_            lego minifigures series 12 - sealed box
# 783           &&5573-2**_                        lego build & play (red tub)
# 811           &&242B-1**_  international flags - britain, france, austria...
# 844         &&850646-1**_  lego® teenage mutant ninja turtles™ donatello ...
# 887         &&fruit5-1**_            melon - hong kong lego show promotional
# 921        &&4000008-1**_  lego inside tour exclusive 2013 edition – vill...
# 922      &&Braintree-1**_  lego store grand opening exclusive set, south ...
# 940        &&5004553-1**_                             lego mixels infernites
# 969        &&5002212-1**_       lego® star wars™ chewbacca™ minifigure watch
#
#      year  theme_id  num_parts
# 6    1957       372          1
# 19   2004       229         62
# 54   2009       425         92
# 71   2014       550          0
# 77   2009       497        141
# 90   2011       501          1
# 109  2010       408        143
# 131  2012       501          0
# 142  1998       534          2
# 149  2013       501          0
# 155  2015       551         60
# 156  2014       504        135
# 164  2014       503          0
# 216  1989       468         14
# 219  2004       301         10
# 228  2008       408         65
# 232  2015       501          6
# 253  2009       497          0
# 262  2014       503          0
# 264  2008        48        650
# 303  2013       408          3
# 324  2014       229        106
# 329  2015       586          3
# 356  2014       497          0
# 397  2012       408         15
# 399  2013       503          6
# 403  2014       503          0
# 426  2014       494         20
# 431  2013       502          0
# 445  2000       276       1849
# 505  2015       604        265
# 550  2015       501          0
# 563  2006       519        434
# 573  2010       408        125
# 574  2004       427        103
# 578  2015       604         36
# 592  2011       504         38
# 596  2014       497          4
# 602  2014       503          0
# 608  2014       501          0
# 677  2011       408         15
# 682  2015       584          9
# 685  2013       408         15
# 692  2006        58          0
# 708  2014       501          0
# 747  2005       347        235
# 750  2014       548         60
# 783  2009        37        644
# 811  1961       371          5
# 844  2013       503          0
# 887  2007        33          8
# 921  2013       301        366
# 922  2008       408         58
# 940  2015       584          3
# 969  2013       501          0

# %% [markdown]
# #### Exercise 5
# What's the most words in one name? The least?

# %%
# Your code here
sets_df['name'].str.count(' ').max() + 1
# Out:
# 14

# %%
sets_df['name'].str.count(' ').min() + 1
# Out:
# 1

# %% [markdown]
# #### Exercise 6
# There are strange symbols around the set numbers. Remove them.

# %%
# Your code here
sets_df['set_num'] = sets_df['set_num'].str.strip('&*_')
sets_df
# Out:
#           set_num                                               name  year  \
# 0    TRUFRIENDS-1                                       wishing well  2017
# 1          7958-8  advent calendar 2011 star wars (day  7) - tool...  2011
# 2        71005-15                                       chief wiggum  2014
# 3          6593-1                                      blaze battler  1991
# 4         75916-1                               dilophosaurus ambush  2015
# ..            ...                                                ...   ...
# 995        1668-1                      basic building set trial size  1992
# 996       71237-1                        aquaman and aqua watercraft  2016
# 997        3939-1                                      mia's bedroom  2012
# 998        5161-1                              inverted slope bricks  1987
# 999       10223-1                                     kingdoms joust  2012
#
#      theme_id  num_parts
# 0         494         33
# 1         225          9
# 2         550          6
# 3          74        126
# 4         602        246
# ..        ...        ...
# 995       469         30
# 996       604         43
# 997       494         86
# 998       443         16
# 999       196       1574
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Exercise 7
# Set numbers are in two pieces, separated by '-'. Separate the two pieces from each other. Save the first part as a new column `set_num_prefix` and the second part as `set_num`.

# %%
# Your code here
sets_df[['set_num_prefix', 'set_num']] = sets_df['set_num'].str.split('-', expand=True)
sets_df
# Out:
#     set_num                                               name  year  \
# 0         1                                       wishing well  2017
# 1         8  advent calendar 2011 star wars (day  7) - tool...  2011
# 2        15                                       chief wiggum  2014
# 3         1                                      blaze battler  1991
# 4         1                               dilophosaurus ambush  2015
# ..      ...                                                ...   ...
# 995       1                      basic building set trial size  1992
# 996       1                        aquaman and aqua watercraft  2016
# 997       1                                      mia's bedroom  2012
# 998       1                              inverted slope bricks  1987
# 999       1                                     kingdoms joust  2012
#
#      theme_id  num_parts set_num_prefix
# 0         494         33     TRUFRIENDS
# 1         225          9           7958
# 2         550          6          71005
# 3          74        126           6593
# 4         602        246          75916
# ..        ...        ...            ...
# 995       469         30           1668
# 996       604         43          71237
# 997       494         86           3939
# 998       443         16           5161
# 999       196       1574          10223
#
# [1000 rows x 6 columns]

# %% [markdown]
# #### Exercise 8
# Replace the word 'brick' in the column `name` with the word 'block'.
# Check after to make sure the word 'brick' is no longer in any name.

# %%
# Your code here
sets_df['name'] = sets_df['name'].str.replace('brick', 'block')
sets_df['name'].str.contains('brick').sum()
# Out:
# 0

# %% [markdown]
# #### Exercise 9
# How many sets contain a number in the name?
# How many `set_num_prefix` contain **no** number?

# %%
# Your code here
sets_df['name'].str.contains(r'\d').sum()
# Out:
# 178

# %%
sets_df['set_num_prefix'].str.contains(r'^\D+$').sum()
# Out:
# 16
