# %% [markdown]
# ## Import the Pandas library and create DataFrame
#
# Before doing anything else, you'll need to import Pandas and get some data to work with.

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Claire', 'David', 'Emma'],
    'Age': [25, 30, 22, 28, 26],
    'Department': ['Marketing', 'Finance', 'Sales', 'HR', 'Marketing'],
    'City': ['New York', 'London', 'Paris', 'San Francisco', 'Sydney'],
    'Email': ['alice@example.com', 'bob@example.com', 'claire@example.com', 'david@example.com', 'emma@example.com'],
    'Job_Title' : ['Data Scientist', 'Financial Analyst', 'Sales Executive', 'HR Manager', 'Marketing Specialist'],
    'Full_Name' : ['Alice Johnson', 'Bob Smith', 'Claire Williams', 'David Lee', 'Emma Brown'],
    'Phone' : ['123-456-7890', '987-654-3210', '555-123-4567', '111-222-3333', '444-555-6666'],
    'Address' : ['       123 Main Street', '        456 Park Avenue', '         789 Elm Road', '        321 Oak Street','        555 Maple Lane']
}

df = pd.DataFrame(data)

df
# Out:
#      Name  Age Department           City               Email  \
# 0   Alice   25  Marketing       New York   alice@example.com
# 1     Bob   30    Finance         London     bob@example.com
# 2  Claire   22      Sales          Paris  claire@example.com
# 3   David   28         HR  San Francisco   david@example.com
# 4    Emma   26  Marketing         Sydney    emma@example.com
#
#               Job_Title        Full_Name         Phone  \
# 0        Data Scientist    Alice Johnson  123-456-7890
# 1     Financial Analyst        Bob Smith  987-654-3210
# 2       Sales Executive  Claire Williams  555-123-4567
# 3            HR Manager        David Lee  111-222-3333
# 4  Marketing Specialist       Emma Brown  444-555-6666
#
#                    Address
# 0          123 Main Street
# 1          456 Park Avenue
# 2             789 Elm Road
# 3           321 Oak Street
# 4           555 Maple Lane

# %% [markdown]
# ## The `.str` accessor

# %% [markdown]
# In Pandas, the `.str` accessor allows us to perform various string operations on DataFrame columns containing string values. This provides a convenient and efficient way to work with textual data within DataFrames.

# %% [markdown]
# > **Note:** The `.str` accessor works on Series. To use any of the tools below, be sure to specify which column of a DataFrame you wish to work with.

# %% [markdown]
# ### String indexing and slicing

# %% [markdown]
# We can access individual characters of each string in a DataFrame column using string indexing. Let's select the first letter of each name:

# %%
df['Name'].str[0]
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: Name, dtype: object

# %% [markdown]
# Using a slice in the string indexer, we'll now select the first four characters of each city.

# %%
df['City'].str[:4]
# Out:
# 0    New
# 1    Lond
# 2    Pari
# 3    San
# 4    Sydn
# Name: City, dtype: object

# %% [markdown]
# ### Converting cases

# %% [markdown]
# `.str.lower()`
# With this method you can change all letters to lower case.

# %%
df['Full_Name'].str.lower()
# Out:
# 0      alice johnson
# 1          bob smith
# 2    claire williams
# 3          david lee
# 4         emma brown
# Name: Full_Name, dtype: object

# %% [markdown]
# Similarly, Pandas offers:
#
# `str.upper()`
# Converts all characters to uppercase.
#
# `str.title()`
# Converts the first character of each word to uppercase and the remaining characters to lowercase.
#
# `str.capitalize()`
# Converts first character of the whole string to uppercase and the remaining characters to lowercase.
#
# `str.swapcase()`
# Converts uppercase to lowercase and lowercase to uppercase.
#
# `str.casefold()`
# Removes all case distinctions in the string. This method is meant to deal with the kind of special characters generally not recognized as having upper and lower cases, e.g. "ß" becomes "ss".

# %% [markdown]
# ### Conditions

# %% [markdown]
# `.str.startswith()` and `.str.endswith()`
# Often used for filtering DataFrames, these methods will check if the first or last character(s) in each string match(es) the given string.

# %%
df['Email'].str.startswith('david')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Email, dtype: bool

# %% [markdown]
# `.str.contains()`
# Another useful method for filtering `.str.contains()` checks if any part of each string matches the given string.

# %%
df['Email'].str.contains('@')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Email, dtype: bool

# %% [markdown]
# ### Length and counting

# %% [markdown]
# `.str.len()`
# This method will count and return the number of characters in each string.

# %%
df['Address'].str.len()
# Out:
# 0    22
# 1    23
# 2    21
# 3    22
# 4    22
# Name: Address, dtype: int64

# %% [markdown]
# `.str.count()`
# returns the count of occurrences of a specified substring in each string of the column

# %%
df['Email'].str.count('example')
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Email, dtype: int64

# %% [markdown]
# ### Manipulating strings

# %% [markdown]
# `.str.replace()`
# Used to locate one sub-string and, if it exists, replace it with another.

# %%
df['City'].str.replace('New', 'Old')
# Out:
# 0         Old York
# 1           London
# 2            Paris
# 3    San Francisco
# 4           Sydney
# Name: City, dtype: object

# %% [markdown]
# `.str.strip()`
# It is not uncommon for data to end up carrying certain artefacts of the ETL process, often as leading or tailing characters. Most commonly, this will result in whitespace; `.str.strip()` removes whitespace before and after a string by default, and can remove others when specified.

# %%
df['Address']
# Out:
# 0            123 Main Street
# 1            456 Park Avenue
# 2               789 Elm Road
# 3             321 Oak Street
# 4             555 Maple Lane
# Name: Address, dtype: object

# %%
df['Address'].str.strip()
# Out:
# 0    123 Main Street
# 1    456 Park Avenue
# 2       789 Elm Road
# 3     321 Oak Street
# 4     555 Maple Lane
# Name: Address, dtype: object

# %% [markdown]
# `.str.split()`
# Used to break a string down into its constituent parts, `.str.split()` will search a string for a given character, creating items in a list each time that character is encountered. By default, splits will be made on whitespace.

# %%
df['Full_Name'].str.split()
# Out:
# 0      [Alice, Johnson]
# 1          [Bob, Smith]
# 2    [Claire, Williams]
# 3          [David, Lee]
# 4         [Emma, Brown]
# Name: Full_Name, dtype: object

# %% [markdown]
# The resulting lists can be accessed with a further `.str` followed by an indexer or `.get()`.

# %%
df['Full_Name'].str.split(' ').str[1]
# Out:
# 0     Johnson
# 1       Smith
# 2    Williams
# 3         Lee
# 4       Brown
# Name: Full_Name, dtype: object

# %%
df['Full_Name'].str.split(' ').str.get(1)
# Out:
# 0     Johnson
# 1       Smith
# 2    Williams
# 3         Lee
# 4       Brown
# Name: Full_Name, dtype: object

# %% [markdown]
# ## Regular expressions

# %% [markdown]
# Regular expressions, commonly known as regex, are powerful tools for pattern matching and text manipulation.
# The regex syntax consists of metacharacters, quantifiers, character classes, and more, which define the rules for matching patterns in strings.

# %% [markdown]
# Common Metacharacters and Their Meanings:
#
# **. (Period)**: Matches any character except a newline.
# For example, the pattern a.b will match 'aab', 'acb', 'a9b', but not 'a\nb'.
#
# **\* (Asterisk)**: Matches zero or more occurrences of the preceding character.
#
#  For example, the pattern ab*c will match 'ac', 'abc', 'abbc', 'abbbc', and so on.
#
# **\+ (Plus)**: Matches one or more occurrences of the preceding character.
#
#  For example, the pattern ab+c will match 'abc', 'abbc', 'abbbc', but not 'ac'.
#
# **? (Question Mark)**: Matches zero or one occurrence of the preceding character.
# For example, the pattern colou?r will match both 'color' and 'colour'.
#
# **^ (Caret)**: Matches the start of a string.
# For example, the pattern ^abc will match 'abc' only if it appears at the beginning of a string.
#
# **\$ (Dollar)**: Matches the end of a string.
# For example, the pattern abc$ will match 'abc' only if it appears at the end of a string.
#
# **[ ] (Square Brackets)**: Matches any single character within the specified set.
# For example, the pattern [aeiou] will match any vowel.
#
# **[^] (Caret Inside Square Brackets)**: Matches any single character not within the specified set.
# For example, the pattern [^aeiou] will match any non-vowel.

# %% [markdown]
# Try [this site](https://regex101.com/) for diving deeper into regular expressions.

# %% [markdown]
# ### Regex in Pandas
# In pandas, certain methods allow for regex pattern matching — some by default and others when explicitly set to do so.

# %%
df['Phone'].str.contains(r'\d+-\d+-\d+')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Phone, dtype: bool

# %% [markdown]
# `\d+-\d+-\d+`
# This pattern matches all strings that containg two minus signs with 1 or more number characters between them.

# %% [markdown]
# ## Challenges

# %%
data = {
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'San Francisco', 'London', 'Paris', 'Berlin', 'Rome', 'Tokyo'],
    'Country': ['USA', 'USA', 'USA', 'USA', 'USA', 'UK', 'France', 'Germany', 'Italy', 'Japan'],
    'Population (Millions)': [8.4, 3.9, 2.7, 2.3, 0.9, 8.9, 2.1, 3.7, 2.8, 13.9],
    'Area (km2)': [468.9, 502.8, 227.6, 1, 121.4, 1572, 105.4, 891.8, 1285, 2187],
    'Language': ['English', 'English', 'English', 'English', 'English', 'English', 'French', 'German', 'Italian', 'Japanese'],
    'Currency': ['USD', 'USD', 'USD', 'USD', 'USD', 'GBP', 'EUR', 'EUR', 'EUR', 'JPY'],
    'Continent': ['North America', 'North America', 'North America', 'North America', 'North America', 'Europe', 'Europe', 'Europe', 'Europe', 'Asia'],
    'Is_Capital': [False, False, False, False, False, True, True, True, True, True]
}

cities_df = pd.DataFrame(data)

# Adding more rows
extra_data = {
    'City': ['Sydney', 'Seoul', 'Beijing', 'Moscow', 'Cairo', 'Mumbai'],
    'Country': ['Australia', 'South Korea', 'China', 'Russia', 'Egypt', 'India'],
    'Population (Millions)': [5.3, 9.7, 21.5, 12.5, 9.5, 20.7],
    'Area (km2)': [1687, 605, 16411, 2561, 3034, 603],
    'Language': ['English', 'Korean', 'Mandarin', 'Russian', 'Arabic', 'Hindi'],
    'Currency': ['AUD', 'KRW', 'CNY', 'RUB', 'EGP', 'INR'],
    'Continent': ['Australia', 'Asia', 'Asia', 'Europe', 'Africa', 'Asia'],
    'Is_Capital': [False, True, True, True, True, False]
}

extra_df = pd.DataFrame(extra_data)
cities_df = pd.concat([cities_df, extra_df], ignore_index=True)

cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital
# 0       USD  North America       False
# 1       USD  North America       False
# 2       USD  North America       False
# 3       USD  North America       False
# 4       USD  North America       False
# 5       GBP         Europe        True
# 6       EUR         Europe        True
# 7       EUR         Europe        True
# 8       EUR         Europe        True
# 9       JPY           Asia        True
# 10      AUD      Australia       False
# 11      KRW           Asia        True
# 12      CNY           Asia        True
# 13      RUB         Europe        True
# 14      EGP         Africa        True
# 15      INR           Asia       False

# %% [markdown]
# ### Challenge 1
# Create a new column 'City_Length' that contains the length of each city name

# %%
#Uliana
cities_df['City_Length'] = cities_df['City'].str.len()
cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length
# 0       USD  North America       False            8
# 1       USD  North America       False           11
# 2       USD  North America       False            7
# 3       USD  North America       False            7
# 4       USD  North America       False           13
# 5       GBP         Europe        True            6
# 6       EUR         Europe        True            5
# 7       EUR         Europe        True            6
# 8       EUR         Europe        True            4
# 9       JPY           Asia        True            5
# 10      AUD      Australia       False            6
# 11      KRW           Asia        True            5
# 12      CNY           Asia        True            7
# 13      RUB         Europe        True            6
# 14      EGP         Africa        True            5
# 15      INR           Asia       False            6

# %%
cities_df_copy = cities_df.copy()

# %%
#alt
cities_df_copy['City_Length'] = cities_df_copy['City'].str.strip().str.len()
cities_df_copy
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length
# 0       USD  North America       False            8
# 1       USD  North America       False           11
# 2       USD  North America       False            7
# 3       USD  North America       False            7
# 4       USD  North America       False           13
# 5       GBP         Europe        True            6
# 6       EUR         Europe        True            5
# 7       EUR         Europe        True            6
# 8       EUR         Europe        True            4
# 9       JPY           Asia        True            5
# 10      AUD      Australia       False            6
# 11      KRW           Asia        True            5
# 12      CNY           Asia        True            7
# 13      RUB         Europe        True            6
# 14      EGP         Africa        True            5
# 15      INR           Asia       False            6

# %% [markdown]
# ### Challenge 2
# Convert the 'City' names to uppercase and store them in a new column 'City_Upper'

# %%
#Helmut
cities_df['City_Upper'] = cities_df['City'].str.upper()
cities_df

# %%
#Nilufar
city_up = cities_df['City'].str.upper()
cities_df['City_Upper'] = city_up
cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length     City_Upper
# 0       USD  North America       False            8       NEW YORK
# 1       USD  North America       False           11    LOS ANGELES
# 2       USD  North America       False            7        CHICAGO
# 3       USD  North America       False            7        HOUSTON
# 4       USD  North America       False           13  SAN FRANCISCO
# 5       GBP         Europe        True            6         LONDON
# 6       EUR         Europe        True            5          PARIS
# 7       EUR         Europe        True            6         BERLIN
# 8       EUR         Europe        True            4           ROME
# 9       JPY           Asia        True            5          TOKYO
# 10      AUD      Australia       False            6         SYDNEY
# 11      KRW           Asia        True            5          SEOUL
# 12      CNY           Asia        True            7        BEIJING
# 13      RUB         Europe        True            6         MOSCOW
# 14      EGP         Africa        True            5          CAIRO
# 15      INR           Asia       False            6         MUMBAI

# %% [markdown]
# ### Challenge 3
# Check if the 'City' names end with the letter 'o'. Create a new column 'Ends_With_O' with the boolean results

# %%
#Nora
cities_df['City'].str.endswith('o')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# Name: City, dtype: bool

# %%
#Bernard
cities_df['Ends_With_O'] = cities_df['City'].str.endswith('o')
cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length     City_Upper  \
# 0       USD  North America       False            8       NEW YORK
# 1       USD  North America       False           11    LOS ANGELES
# 2       USD  North America       False            7        CHICAGO
# 3       USD  North America       False            7        HOUSTON
# 4       USD  North America       False           13  SAN FRANCISCO
# 5       GBP         Europe        True            6         LONDON
# 6       EUR         Europe        True            5          PARIS
# 7       EUR         Europe        True            6         BERLIN
# 8       EUR         Europe        True            4           ROME
# 9       JPY           Asia        True            5          TOKYO
# 10      AUD      Australia       False            6         SYDNEY
# 11      KRW           Asia        True            5          SEOUL
# 12      CNY           Asia        True            7        BEIJING
# 13      RUB         Europe        True            6         MOSCOW
# 14      EGP         Africa        True            5          CAIRO
# 15      INR           Asia       False            6         MUMBAI
#
#     Ends_With_O
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False

# %%
cities_df_copy['Ends_With_O'] = cities_df_copy['City'].str.contains('o$')
cities_df_copy
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length  Ends_With_O
# 0       USD  North America       False            8        False
# 1       USD  North America       False           11        False
# 2       USD  North America       False            7         True
# 3       USD  North America       False            7        False
# 4       USD  North America       False           13         True
# 5       GBP         Europe        True            6        False
# 6       EUR         Europe        True            5        False
# 7       EUR         Europe        True            6        False
# 8       EUR         Europe        True            4        False
# 9       JPY           Asia        True            5         True
# 10      AUD      Australia       False            6        False
# 11      KRW           Asia        True            5        False
# 12      CNY           Asia        True            7        False
# 13      RUB         Europe        True            6        False
# 14      EGP         Africa        True            5         True
# 15      INR           Asia       False            6        False

# %% [markdown]
# ### Challenge 4
# Replace the word 'York' in 'City' names with 'Ville' and update the 'City' column accordingly

# %%
#Monika
cities_df['City'] = cities_df['City'].str.replace('York', 'Ville')
cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0       New Ville          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length     City_Upper  \
# 0       USD  North America       False            8       NEW YORK
# 1       USD  North America       False           11    LOS ANGELES
# 2       USD  North America       False            7        CHICAGO
# 3       USD  North America       False            7        HOUSTON
# 4       USD  North America       False           13  SAN FRANCISCO
# 5       GBP         Europe        True            6         LONDON
# 6       EUR         Europe        True            5          PARIS
# 7       EUR         Europe        True            6         BERLIN
# 8       EUR         Europe        True            4           ROME
# 9       JPY           Asia        True            5          TOKYO
# 10      AUD      Australia       False            6         SYDNEY
# 11      KRW           Asia        True            5          SEOUL
# 12      CNY           Asia        True            7        BEIJING
# 13      RUB         Europe        True            6         MOSCOW
# 14      EGP         Africa        True            5          CAIRO
# 15      INR           Asia       False            6         MUMBAI
#
#     Ends_With_O
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False

# %% [markdown]
# ### Challenge 5
# Create a new column 'Country_Code' by extracting the first three characters from the 'Country' names

# %%
#Nic
cities_df['Country_Code'] = cities_df['Country'].str[:3]
cities_df
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0       New Ville          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length     City_Upper  \
# 0       USD  North America       False            8       NEW YORK
# 1       USD  North America       False           11    LOS ANGELES
# 2       USD  North America       False            7        CHICAGO
# 3       USD  North America       False            7        HOUSTON
# 4       USD  North America       False           13  SAN FRANCISCO
# 5       GBP         Europe        True            6         LONDON
# 6       EUR         Europe        True            5          PARIS
# 7       EUR         Europe        True            6         BERLIN
# 8       EUR         Europe        True            4           ROME
# 9       JPY           Asia        True            5          TOKYO
# 10      AUD      Australia       False            6         SYDNEY
# 11      KRW           Asia        True            5          SEOUL
# 12      CNY           Asia        True            7        BEIJING
# 13      RUB         Europe        True            6         MOSCOW
# 14      EGP         Africa        True            5          CAIRO
# 15      INR           Asia       False            6         MUMBAI
#
#     Ends_With_O Country_Code
# 0         False          USA
# 1         False          USA
# 2          True          USA
# 3         False          USA
# 4          True          USA
# 5         False           UK
# 6         False          Fra
# 7         False          Ger
# 8         False          Ita
# 9          True          Jap
# 10        False          Aus
# 11        False          Sou
# 12        False          Chi
# 13        False          Rus
# 14         True          Egy
# 15        False          Ind

# %%
#Uliana
cities_df_copy['Counrty_Code']=cities_df_copy['Country'].str.slice(0,3)
cities_df_copy
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length  Ends_With_O Counrty_Code
# 0       USD  North America       False            8        False          USA
# 1       USD  North America       False           11        False          USA
# 2       USD  North America       False            7         True          USA
# 3       USD  North America       False            7        False          USA
# 4       USD  North America       False           13         True          USA
# 5       GBP         Europe        True            6        False           UK
# 6       EUR         Europe        True            5        False          Fra
# 7       EUR         Europe        True            6        False          Ger
# 8       EUR         Europe        True            4        False          Ita
# 9       JPY           Asia        True            5         True          Jap
# 10      AUD      Australia       False            6        False          Aus
# 11      KRW           Asia        True            5        False          Sou
# 12      CNY           Asia        True            7        False          Chi
# 13      RUB         Europe        True            6        False          Rus
# 14      EGP         Africa        True            5         True          Egy
# 15      INR           Asia       False            6        False          Ind

# %%
#Helmut
cities_df_copy['Country_Code_Upper'] = cities_df_copy['Country'].str[:3].str.upper()
cities_df_copy
# Out:
#              City      Country  Population (Millions)  Area (km2)  Language  \
# 0        New York          USA                    8.4       468.9   English
# 1     Los Angeles          USA                    3.9       502.8   English
# 2         Chicago          USA                    2.7       227.6   English
# 3         Houston          USA                    2.3         1.0   English
# 4   San Francisco          USA                    0.9       121.4   English
# 5          London           UK                    8.9      1572.0   English
# 6           Paris       France                    2.1       105.4    French
# 7          Berlin      Germany                    3.7       891.8    German
# 8            Rome        Italy                    2.8      1285.0   Italian
# 9           Tokyo        Japan                   13.9      2187.0  Japanese
# 10         Sydney    Australia                    5.3      1687.0   English
# 11          Seoul  South Korea                    9.7       605.0    Korean
# 12        Beijing        China                   21.5     16411.0  Mandarin
# 13         Moscow       Russia                   12.5      2561.0   Russian
# 14          Cairo        Egypt                    9.5      3034.0    Arabic
# 15         Mumbai        India                   20.7       603.0     Hindi
#
#    Currency      Continent  Is_Capital  City_Length  Ends_With_O Counrty_Code  \
# 0       USD  North America       False            8        False          USA
# 1       USD  North America       False           11        False          USA
# 2       USD  North America       False            7         True          USA
# 3       USD  North America       False            7        False          USA
# 4       USD  North America       False           13         True          USA
# 5       GBP         Europe        True            6        False           UK
# 6       EUR         Europe        True            5        False          Fra
# 7       EUR         Europe        True            6        False          Ger
# 8       EUR         Europe        True            4        False          Ita
# 9       JPY           Asia        True            5         True          Jap
# 10      AUD      Australia       False            6        False          Aus
# 11      KRW           Asia        True            5        False          Sou
# 12      CNY           Asia        True            7        False          Chi
# 13      RUB         Europe        True            6        False          Rus
# 14      EGP         Africa        True            5         True          Egy
# 15      INR           Asia       False            6        False          Ind
#
#    Country_Code_Upper
# 0                 USA
# 1                 USA
# 2                 USA
# 3                 USA
# 4                 USA
# 5                  UK
# 6                 FRA
# 7                 GER
# 8                 ITA
# 9                 JAP
# 10                AUS
# 11                SOU
# 12                CHI
# 13                RUS
# 14                EGY
# 15                IND

# %% [markdown]
# ### Challenge 6
# Count the occurrences of the letter 'a' in each 'City' name

# %%
#Bernard
cities_df['City'].str.count('a')
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     2
# 5     0
# 6     1
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# Name: City, dtype: int64

# %%
cities_df['City'].str.count('a').sum() # will return 6
# Out:
# 6

# %%
#alt
cities_df['City'].str.contains('a')#.sum() # will return 5 -> 5 x True = 5 x 1 = 5
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# Name: City, dtype: bool

# %% [markdown]
# ### Challenge 7
# Check if the 'City' names start with the letter 'C' and end with the letter 'o'

# %%
#Nilufar
cities_df['City'].str.startswith('C') & cities_df['City'].str.endswith('o')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# Name: City, dtype: bool

# %%
#alt
cities_df['City'].str.contains('^C') & cities_df['City'].str.contains('o$')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# Name: City, dtype: bool

# %%
#Uliana
cities_df['City'].str.contains(r"C.*o")

# %%
cities_df['City'].str.contains(r"^C.*o$")

# %%
#Nora
cities_df['City'].str.contains(r'^C.*o$', regex=True)

# %% [markdown]
# ### Challenge 8
# Check if the 'City' names contain exactly two words

# %%
cities_df_copy['City']
# Out:
# 0          New York
# 1       Los Angeles
# 2           Chicago
# 3           Houston
# 4     San Francisco
# 5            London
# 6             Paris
# 7            Berlin
# 8              Rome
# 9             Tokyo
# 10           Sydney
# 11            Seoul
# 12          Beijing
# 13           Moscow
# 14            Cairo
# 15           Mumbai
# Name: City, dtype: object

# %%
#Uliana
cities_df_copy['City'].str.contains(r" {1}")
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
#Nic
cities_df['City'].str.split().str.len() == 2
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
#Nora
cities_df['City'].str.count(' ') == 1
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
cities_df.loc[cities_df['City'].str.count(' ') == 1, :]
# Out:
#             City Country  Population (Millions)  Area (km2) Language Currency  \
# 0      New Ville     USA                    8.4       468.9  English      USD
# 1    Los Angeles     USA                    3.9       502.8  English      USD
# 4  San Francisco     USA                    0.9       121.4  English      USD
#
#        Continent  Is_Capital  City_Length     City_Upper  Ends_With_O  \
# 0  North America       False            8       NEW YORK        False
# 1  North America       False           11    LOS ANGELES        False
# 4  North America       False           13  SAN FRANCISCO         True
#
#   Country_Code
# 0          USA
# 1          USA
# 4          USA

# %%
#alt
cities_df['City'].str.split().apply(len) == 2
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
#Uliana_2
cities_df_copy['City'].str.contains(r"^.+ .+$")
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
#alt_2
cities_df['City'].str.contains(r'^\w+\s\w+$')
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: City, dtype: bool

# %%
cities_df['City']
# Out:
# 0         New Ville
# 1       Los Angeles
# 2           Chicago
# 3           Houston
# 4     San Francisco
# 5            London
# 6             Paris
# 7            Berlin
# 8              Rome
# 9             Tokyo
# 10           Sydney
# 11            Seoul
# 12          Beijing
# 13           Moscow
# 14            Cairo
# 15           Mumbai
# Name: City, dtype: object

# %%
#alt_3
for city in cities_df['City']:
  if len(city.split()) == 2:
    print(city)
# Out:
# New Ville
# Los Angeles
# San Francisco
