# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone
from dotenv import load_dotenv
import os

# using colab secrets to store our passwords and keys

# %% [markdown]
# # Making the API call and viewing the json

# %%
load_dotenv()  # Load environment variables from .env file

api_key = os.getenv('aerodatabox_api_key')
icao = "EDDB"
date = datetime.now().date()
time_1 = "00:00"
time_2 = "11:59"

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{date}T{time_1}/{date}T{time_2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET",
                            url,
                            headers = headers,
                            params = querystring)

flights_json = response.json()

flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 03:47Z',
#      'local': '2024-11-06 04:47+01:00'},
#     'revisedTime': {'utc': '2024-11-06 03:47Z',
#      'local': '2024-11-06 04:47+01:00'},
#     'runwayTime': {'utc': '2024-11-06 03:47Z',
#      'local': '2024-11-06 04:47+01:00'},
#     'runway': '14L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 04:33Z',
#      'local': '2024-11-06 05:33+01:00'},
#     'revisedTime': {'utc': '2024-11-06 04:33Z',
#      'local': '2024-11-06 05:33+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'DJ 6228',
#    'callSign': 'SRR6228',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-SRJ', 'modeS': '45CE4A', 'model': 'Boeing 767-200'},
#    'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#   {'departure': {'airport': {'icao': 'ZBAA',
#      'iata': 'PEK',
#      'name': 'Beijing',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2024-11-05 19:20Z',
#      'local': '2024-11-06 03:20+08:00'},
#     'revisedTime': {'utc': '2024-11-05 19:30Z',
#      'local': '2024-11-06 03:30+08:00'},
#     'runwayTime': {'utc': '2024-11-05 19:34Z',
#      'local': '2024-11-06 03:34+08:00'},
#     'terminal': '2',
#     'checkInDesk': 'C11-C15',
#     'gate': '14',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 05:40Z',
#      'local': '2024-11-06 06:40+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:00Z',
#      'local': '2024-11-06 06:00+01:00'},
#     'runwayTime': {'utc': '2024-11-06 05:00Z',
#      'local': '2024-11-06 06:00+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'HU 489',
#    'callSign': 'CHH489',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'B-1048', 'modeS': '781318', 'model': 'Airbus A330'},
#    'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#   {'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2024-11-05 23:40Z',
#      'local': '2024-11-06 02:40+03:00'},
#     'revisedTime': {'utc': '2024-11-05 23:39Z',
#      'local': '2024-11-06 02:39+03:00'},
#     'runwayTime': {'utc': '2024-11-06 00:01Z',
#      'local': '2024-11-06 03:01+03:00'},
#     'gate': 'C61',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 05:55Z',
#      'local': '2024-11-06 06:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:37Z',
#      'local': '2024-11-06 06:37+01:00'},
#     'runwayTime': {'utc': '2024-11-06 05:37Z',
#      'local': '2024-11-06 06:37+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'callSign': 'QTR55H',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-BHI', 'modeS': '06A2EC', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 05:39Z',
#      'local': '2024-11-06 06:39+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:39Z',
#      'local': '2024-11-06 06:39+01:00'},
#     'runwayTime': {'utc': '2024-11-06 05:39Z',
#      'local': '2024-11-06 06:39+01:00'},
#     'runway': '14L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 06:24Z',
#      'local': '2024-11-06 07:24+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:24Z',
#      'local': '2024-11-06 07:24+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 1YX',
#    'callSign': 'GWI1YX',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 05:30Z',
#      'local': '2024-11-06 06:30+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 06:40Z',
#      'local': '2024-11-06 07:40+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 05:20Z',
#      'local': '2024-11-06 06:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:20Z',
#      'local': '2024-11-06 06:20+01:00'},
#     'terminal': '3',
#     'gate': '337',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 06:35Z',
#      'local': '2024-11-06 07:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:38Z',
#      'local': '2024-11-06 07:38+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-11-05 22:50Z',
#      'local': '2024-11-05 17:50-05:00'},
#     'revisedTime': {'utc': '2024-11-05 23:25Z',
#      'local': '2024-11-05 18:25-05:00'},
#     'runwayTime': {'utc': '2024-11-05 23:25Z',
#      'local': '2024-11-05 18:25-05:00'},
#     'terminal': 'C',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 06:55Z',
#      'local': '2024-11-06 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:40Z',
#      'local': '2024-11-06 07:40+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:40Z',
#      'local': '2024-11-06 07:40+01:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B2',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'callSign': 'UAL962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N59053', 'modeS': 'A7A08A', 'model': 'Boeing 767-400'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'OEJN',
#      'iata': 'JED',
#      'name': 'Jeddah',
#      'timeZone': 'Asia/Riyadh'},
#     'scheduledTime': {'utc': '2024-11-06 01:00Z',
#      'local': '2024-11-06 04:00+03:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 08:15+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:43Z',
#      'local': '2024-11-06 07:43+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:43Z',
#      'local': '2024-11-06 07:43+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'XY 643',
#    'callSign': 'KNE643',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HZ-NS75',
#     'modeS': '717C81',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 05:45Z',
#      'local': '2024-11-06 06:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:45Z',
#      'local': '2024-11-06 06:45+01:00'},
#     'runwayTime': {'utc': '2024-11-06 05:55Z',
#      'local': '2024-11-06 06:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A14',
#     'runway': '25C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 06:55Z',
#      'local': '2024-11-06 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:46Z',
#      'local': '2024-11-06 07:46+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:46Z',
#      'local': '2024-11-06 07:46+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'callSign': 'DLH1EL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRO', 'modeS': '3C664F', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg',
#      'timeZone': 'Europe/Luxembourg'},
#     'scheduledTime': {'utc': '2024-11-06 05:30Z',
#      'local': '2024-11-06 06:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 05:27Z',
#      'local': '2024-11-06 06:27+01:00'},
#     'runwayTime': {'utc': '2024-11-06 05:40Z',
#      'local': '2024-11-06 06:40+01:00'},
#     'terminal': 'A',
#     'gate': 'B04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:00Z',
#      'local': '2024-11-06 08:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:56Z',
#      'local': '2024-11-06 07:56+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:54Z',
#      'local': '2024-11-06 07:54+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9471',
#    'callSign': 'LGL91B',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LQC',
#     'modeS': '4D00D7',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-06 06:10Z',
#      'local': '2024-11-06 07:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:13Z',
#      'local': '2024-11-06 07:13+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:14Z',
#      'local': '2024-11-06 07:14+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F32',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:25Z',
#      'local': '2024-11-06 08:25+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:05Z',
#      'local': '2024-11-06 08:05+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA223',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LZD', 'modeS': '440605', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 05:30Z',
#      'local': '2024-11-06 06:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:05Z',
#      'local': '2024-11-06 08:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:08Z',
#      'local': '2024-11-06 08:08+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 121',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 06:00Z',
#      'local': '2024-11-06 07:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:00Z',
#      'local': '2024-11-06 07:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:10Z',
#      'local': '2024-11-06 08:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:11Z',
#      'local': '2024-11-06 08:11+01:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'VL 1928',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGK', 'modeS': '3C48EB', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-11-06 05:05Z',
#      'local': '2024-11-06 07:05+02:00'},
#     'revisedTime': {'utc': '2024-11-06 05:28Z',
#      'local': '2024-11-06 07:28+02:00'},
#     'runwayTime': {'utc': '2024-11-06 05:43Z',
#      'local': '2024-11-06 07:43+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '14',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:00Z',
#      'local': '2024-11-06 08:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:13Z',
#      'local': '2024-11-06 08:13+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LXI', 'modeS': '461F6A', 'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-06 06:05Z',
#      'local': '2024-11-06 07:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:19Z',
#      'local': '2024-11-06 07:19+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:19Z',
#      'local': '2024-11-06 07:19+01:00'},
#     'terminal': '2G',
#     'runway': '08L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:55Z',
#      'local': '2024-11-06 08:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:36Z',
#      'local': '2024-11-06 08:36+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR1434',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HBLK', 'modeS': '39856A', 'model': 'Embraer 190'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 06:15Z',
#      'local': '2024-11-06 07:15+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:15Z',
#      'local': '2024-11-06 07:15+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:34Z',
#      'local': '2024-11-06 07:34+01:00'},
#     'checkInDesk': '1',
#     'gate': 'A74',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:45Z',
#      'local': '2024-11-06 08:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:41Z',
#      'local': '2024-11-06 08:41+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JBG',
#     'modeS': '4B17E4',
#     'model': 'Airbus A220-100'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 06:45Z',
#      'local': '2024-11-06 07:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:45Z',
#      'local': '2024-11-06 07:45+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:53Z',
#      'local': '2024-11-06 07:53+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A28',
#     'runway': '18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 07:55Z',
#      'local': '2024-11-06 08:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:45Z',
#      'local': '2024-11-06 08:45+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH5CW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISK', 'modeS': '3C666B', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#      'local': '2024-11-06 09:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:50Z',
#      'local': '2024-11-06 08:50+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4075',
#    'callSign': 'EJU93LP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICM', 'modeS': '440452', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:30Z',
#      'local': '2024-11-06 07:30+01:00'},
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#      'local': '2024-11-06 09:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:50Z',
#      'local': '2024-11-06 08:50+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4075',
#    'callSign': 'EJU93LP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICM', 'modeS': '440452', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 07:00Z',
#      'local': '2024-11-06 08:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:00Z',
#      'local': '2024-11-06 08:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#      'local': '2024-11-06 09:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:09Z',
#      'local': '2024-11-06 09:09+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:09Z',
#      'local': '2024-11-06 09:09+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1930',
#    'callSign': 'DLH2X',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINQ',
#     'modeS': '3C65D1',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo',
#      'timeZone': 'Asia/Jerusalem'},
#     'scheduledTime': {'utc': '2024-11-06 04:00Z',
#      'local': '2024-11-06 06:00+02:00'},
#     'revisedTime': {'utc': '2024-11-06 04:15Z',
#      'local': '2024-11-06 06:15+02:00'},
#     'runwayTime': {'utc': '2024-11-06 04:15Z',
#      'local': '2024-11-06 06:15+02:00'},
#     'terminal': '3',
#     'runway': '26',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:30Z',
#      'local': '2024-11-06 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:12Z',
#      'local': '2024-11-06 09:12+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LY 2371',
#    'callSign': 'ELY2371',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4X-EKH', 'modeS': '73806D', 'model': 'Boeing 737'},
#    'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-06 07:05Z',
#      'local': '2024-11-06 08:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:07Z',
#      'local': '2024-11-06 08:07+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 08:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'D84',
#     'runway': '24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:25Z',
#      'local': '2024-11-06 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:15Z',
#      'local': '2024-11-06 09:15+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1771',
#    'callSign': 'KLM1771',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:26Z',
#      'local': '2024-11-06 09:26+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:26Z',
#      'local': '2024-11-06 09:26+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1721',
#    'callSign': 'THY4CM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-LPA',
#     'modeS': '4BB201',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-11-06 07:30Z',
#      'local': '2024-11-06 08:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:30Z',
#      'local': '2024-11-06 08:30+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:48Z',
#      'local': '2024-11-06 08:48+01:00'},
#     'terminal': 'erminal3',
#     'gate': 'B6',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:30Z',
#      'local': '2024-11-06 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:29Z',
#      'local': '2024-11-06 09:29+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:29Z',
#      'local': '2024-11-06 09:29+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 1673',
#    'callSign': 'SAS1673',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-DOX',
#     'modeS': '4A91F8',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-06 05:00Z',
#      'local': '2024-11-06 08:00+03:00'},
#     'revisedTime': {'utc': '2024-11-06 05:00Z',
#      'local': '2024-11-06 08:00+03:00'},
#     'terminal': '2',
#     'checkInDesk': '238-240',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:20Z',
#      'local': '2024-11-06 09:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:32Z',
#      'local': '2024-11-06 09:32+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:31Z',
#      'local': '2024-11-06 09:31+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A2',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FH 1281',
#    'callSign': 'FHY1281',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-FBR', 'modeS': '4B9852', 'model': 'Airbus A320'},
#    'airline': {'name': 'Freebird', 'iata': 'FH', 'icao': 'FHY'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 07:20Z',
#      'local': '2024-11-06 08:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 08:15+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:22Z',
#      'local': '2024-11-06 08:22+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A84',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:34Z',
#      'local': '2024-11-06 09:34+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5188',
#    'callSign': 'EJU53ZL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 07:20Z',
#      'local': '2024-11-06 08:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 08:15+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:22Z',
#      'local': '2024-11-06 08:22+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A84',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:34Z',
#      'local': '2024-11-06 09:34+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5188',
#    'callSign': 'EJU53ZL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2024-11-06 06:20Z',
#      'local': '2024-11-06 06:20+00:00'},
#     'revisedTime': {'utc': '2024-11-06 06:20Z',
#      'local': '2024-11-06 06:20+00:00'},
#     'runwayTime': {'utc': '2024-11-06 06:44Z',
#      'local': '2024-11-06 06:44+00:00'},
#     'terminal': '2',
#     'checkInDesk': '29-56',
#     'gate': '418',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:38Z',
#      'local': '2024-11-06 09:38+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:37Z',
#      'local': '2024-11-06 09:37+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 332',
#    'callSign': 'EIN3JE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-NSA',
#     'modeS': '4CAD7A',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 07:30Z',
#      'local': '2024-11-06 08:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:30Z',
#      'local': '2024-11-06 08:30+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:42Z',
#      'local': '2024-11-06 08:42+01:00'},
#     'checkInDesk': '1',
#     'gate': 'A75',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:55Z',
#      'local': '2024-11-06 09:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:47Z',
#      'local': '2024-11-06 09:47+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'B2',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 976',
#    'callSign': 'SWR2HD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JVO', 'modeS': '4B19F4', 'model': 'Embraer 190'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 07:45Z',
#      'local': '2024-11-06 08:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 07:45Z',
#      'local': '2024-11-06 08:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A15',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:55Z',
#      'local': '2024-11-06 09:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 176',
#    'callSign': 'DLH9KK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINM',
#     'modeS': '3C65CD',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-06 07:10Z',
#      'local': '2024-11-06 07:10+00:00'},
#     'revisedTime': {'utc': '2024-11-06 07:24Z',
#      'local': '2024-11-06 07:24+00:00'},
#     'runwayTime': {'utc': '2024-11-06 07:25Z',
#      'local': '2024-11-06 07:25+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:05Z',
#      'local': '2024-11-06 10:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:53Z',
#      'local': '2024-11-06 09:53+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 990',
#    'callSign': 'BAW990G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUPK', 'modeS': '40087A', 'model': 'Airbus A319'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LGAV',
#      'iata': 'ATH',
#      'name': 'Athens',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2024-11-06 05:35Z',
#      'local': '2024-11-06 07:35+02:00'},
#     'revisedTime': {'utc': '2024-11-06 06:29Z',
#      'local': '2024-11-06 08:29+02:00'},
#     'terminal': 'I',
#     'checkInDesk': '11---15',
#     'gate': 'A03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:54Z',
#      'local': '2024-11-06 09:54+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TV 720',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Tibet', 'iata': 'TV', 'icao': 'TBA'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-06 06:15Z',
#      'local': '2024-11-06 07:15+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:22Z',
#      'local': '2024-11-06 07:22+01:00'},
#     'runwayTime': {'utc': '2024-11-06 06:40Z',
#      'local': '2024-11-06 07:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'A16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:00Z',
#      'local': '2024-11-06 10:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:57Z',
#      'local': '2024-11-06 09:57+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1882',
#    'callSign': 'VLG1882',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NYC',
#     'modeS': '34734F',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 08:00Z',
#      'local': '2024-11-06 09:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:00Z',
#      'local': '2024-11-06 09:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:10Z',
#      'local': '2024-11-06 10:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:01Z',
#      'local': '2024-11-06 10:01+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1934',
#    'callSign': 'DLH5T',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUD',
#     'modeS': '3C66A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-06 07:25Z',
#      'local': '2024-11-06 07:25+00:00'},
#     'revisedTime': {'utc': '2024-11-06 07:29Z',
#      'local': '2024-11-06 07:29+00:00'},
#     'runwayTime': {'utc': '2024-11-06 07:39Z',
#      'local': '2024-11-06 07:39+00:00'},
#     'terminal': '1',
#     'gate': '42',
#     'runway': '22',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:05Z',
#      'local': '2024-11-06 10:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:04Z',
#      'local': '2024-11-06 10:04+01:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 145',
#    'callSign': 'RYR4DA',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QBO', 'modeS': '4D221D', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 08:05Z',
#      'local': '2024-11-06 09:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:00Z',
#      'local': '2024-11-06 09:00+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:07Z',
#      'local': '2024-11-06 09:07+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A85',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#      'local': '2024-11-06 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:12Z',
#      'local': '2024-11-06 10:12+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 4406',
#    'callSign': 'EWG44U',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-06 08:05Z',
#      'local': '2024-11-06 09:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:00Z',
#      'local': '2024-11-06 09:00+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:07Z',
#      'local': '2024-11-06 09:07+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A85',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#      'local': '2024-11-06 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:12Z',
#      'local': '2024-11-06 10:12+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:13Z',
#      'local': '2024-11-06 10:13+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8761',
#    'callSign': 'EWG44U',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 07:15+00:00'},
#     'revisedTime': {'utc': '2024-11-06 07:15Z',
#      'local': '2024-11-06 07:15+00:00'},
#     'runwayTime': {'utc': '2024-11-06 07:24Z',
#      'local': '2024-11-06 07:24+00:00'},
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '107',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:25Z',
#      'local': '2024-11-06 10:25+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:16Z',
#      'local': '2024-11-06 10:16+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:15Z',
#      'local': '2024-11-06 10:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'callSign': 'RYR68RF',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EKW', 'modeS': '4CA815', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIPB',
#      'iata': 'BZO',
#      'name': 'Bolzano',
#      'timeZone': 'Europe/Rome'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:20Z',
#      'local': '2024-11-06 10:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:20Z',
#      'local': '2024-11-06 10:20+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:20Z',
#      'local': '2024-11-06 10:20+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'SWU 1950',
#    'callSign': 'SWU1950',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-BEL',
#     'modeS': '4D2320',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'SWU'}},
#   {'departure': {'airport': {'icao': 'LIPB',
#      'iata': 'BZO',
#      'name': 'Bolzano',
#      'timeZone': 'Europe/Rome'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:40Z',
#      'local': '2024-11-06 10:40+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:21Z',
#      'local': '2024-11-06 10:21+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BQ 1950',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-BEL',
#     'modeS': '4D2320',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'BQ'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-06 08:20Z',
#      'local': '2024-11-06 09:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:27Z',
#      'local': '2024-11-06 09:27+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:28Z',
#      'local': '2024-11-06 09:28+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F25',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:35Z',
#      'local': '2024-11-06 10:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:23Z',
#      'local': '2024-11-06 10:23+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:22Z',
#      'local': '2024-11-06 10:22+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 225',
#    'callSign': 'AUA225S',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LWF', 'modeS': '440822', 'model': 'Embraer 195'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest',
#      'timeZone': 'Europe/Budapest'},
#     'scheduledTime': {'utc': '2024-11-06 07:55Z',
#      'local': '2024-11-06 08:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:16Z',
#      'local': '2024-11-06 09:16+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:17Z',
#      'local': '2024-11-06 09:17+01:00'},
#     'terminal': '2B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:25Z',
#      'local': '2024-11-06 10:25+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:26Z',
#      'local': '2024-11-06 10:26+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 197',
#    'callSign': 'RYR81UJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUE', 'modeS': '4D2303', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'OEJN',
#      'iata': 'JED',
#      'name': 'Jeddah',
#      'timeZone': 'Asia/Riyadh'},
#     'scheduledTime': {'utc': '2024-11-06 03:30Z',
#      'local': '2024-11-06 06:30+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:35Z',
#      'local': '2024-11-06 10:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:30Z',
#      'local': '2024-11-06 10:30+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 1159',
#    'callSign': 'EWG1159',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENC',
#     'modeS': '3C55C3',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EPWA',
#      'iata': 'WAW',
#      'name': 'Warsaw',
#      'timeZone': 'Europe/Warsaw'},
#     'scheduledTime': {'utc': '2024-11-06 08:20Z',
#      'local': '2024-11-06 09:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:39Z',
#      'local': '2024-11-06 09:39+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:39Z',
#      'local': '2024-11-06 09:39+01:00'},
#     'runway': '33',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#      'local': '2024-11-06 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:32Z',
#      'local': '2024-11-06 10:32+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 387',
#    'callSign': 'LOT7AE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-LIA', 'modeS': '48AD00', 'model': 'Embraer 175'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'departure': {'airport': {'icao': 'LEMD',
#      'iata': 'MAD',
#      'name': 'Madrid',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-06 06:50Z',
#      'local': '2024-11-06 07:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 06:58Z',
#      'local': '2024-11-06 07:58+01:00'},
#     'runwayTime': {'utc': '2024-11-06 07:11Z',
#      'local': '2024-11-06 08:11+01:00'},
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'J40',
#     'runway': '36R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:55Z',
#      'local': '2024-11-06 10:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:41Z',
#      'local': '2024-11-06 10:41+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 1801',
#    'callSign': 'IBS18JP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-OCC',
#     'modeS': '347553',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Düsseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 07:40Z',
#      'local': '2024-11-06 08:40+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:38Z',
#      'local': '2024-11-06 09:38+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:52Z',
#      'local': '2024-11-06 09:52+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:46Z',
#      'local': '2024-11-06 10:46+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8041',
#    'callSign': 'GWI2R',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-06 06:50Z',
#      'local': '2024-11-06 09:50+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:50Z',
#      'local': '2024-11-06 10:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:49Z',
#      'local': '2024-11-06 10:49+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
# ...
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-11-06 08:30Z',
#      'local': '2024-11-06 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:41Z',
#      'local': '2024-11-06 09:41+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:53Z',
#      'local': '2024-11-06 09:53+01:00'},
#     'terminal': '5',
#     'checkInDesk': '71-80',
#     'gate': 'E4',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:05Z',
#      'local': '2024-11-06 11:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:06Z',
#      'local': '2024-11-06 11:06+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 2677',
#    'callSign': 'SAS2677',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-SIN',
#     'modeS': '4CAD41',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels',
#      'timeZone': 'Europe/Brussels'},
#     'scheduledTime': {'utc': '2024-11-06 08:40Z',
#      'local': '2024-11-06 09:40+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:05Z',
#      'local': '2024-11-06 10:05+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:06Z',
#      'local': '2024-11-06 10:06+01:00'},
#     'checkInDesk': '05',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:05Z',
#      'local': '2024-11-06 11:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:06Z',
#      'local': '2024-11-06 11:06+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2581',
#    'callSign': 'BEL8CE',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-06 08:25Z',
#      'local': '2024-11-06 08:25+00:00'},
#     'revisedTime': {'utc': '2024-11-06 08:45Z',
#      'local': '2024-11-06 08:45+00:00'},
#     'runwayTime': {'utc': '2024-11-06 08:46Z',
#      'local': '2024-11-06 08:46+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:20Z',
#      'local': '2024-11-06 11:20+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:06Z',
#      'local': '2024-11-06 11:06+01:00'},
#     'terminal': '1',
#     'gate': 'Y07',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 992',
#    'callSign': 'BAW992G',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-NEOW', 'modeS': '4077E0', 'model': 'Airbus A321'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 09:20Z',
#      'local': '2024-11-06 10:20+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:30Z',
#      'local': '2024-11-06 11:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:15Z',
#      'local': '2024-11-06 11:15+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 08:45Z',
#      'local': '2024-11-06 09:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:05Z',
#      'local': '2024-11-06 10:05+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:31Z',
#      'local': '2024-11-06 10:31+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A18',
#     'runway': '25C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 09:55Z',
#      'local': '2024-11-06 10:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:18Z',
#      'local': '2024-11-06 11:18+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 178',
#    'callSign': 'DLH178',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIWA', 'modeS': '3C66E1', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LBSF',
#      'iata': 'SOF',
#      'name': 'Sofia',
#      'timeZone': 'Europe/Sofia'},
#     'scheduledTime': {'utc': '2024-11-06 08:20Z',
#      'local': '2024-11-06 10:20+02:00'},
#     'revisedTime': {'utc': '2024-11-06 08:37Z',
#      'local': '2024-11-06 10:37+02:00'},
#     'runwayTime': {'utc': '2024-11-06 08:37Z',
#      'local': '2024-11-06 10:37+02:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:30Z',
#      'local': '2024-11-06 11:30+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:25Z',
#      'local': '2024-11-06 11:25+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'FB 319',
#    'callSign': 'LZB319',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LZ-LIS',
#     'modeS': '452163',
#     'model': 'Airbus A220-100'},
#    'airline': {'name': 'Bulgaria Air', 'iata': 'FB', 'icao': 'LZB'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 09:00Z',
#      'local': '2024-11-06 10:00+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:00Z',
#      'local': '2024-11-06 10:00+01:00'},
#     'terminal': '3',
#     'gate': '173',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:15Z',
#      'local': '2024-11-06 11:15+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:28Z',
#      'local': '2024-11-06 11:28+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8003',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:35Z',
#      'local': '2024-11-06 09:35+01:00'},
#     'runwayTime': {'utc': '2024-11-06 08:55Z',
#      'local': '2024-11-06 09:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:45Z',
#      'local': '2024-11-06 11:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:31Z',
#      'local': '2024-11-06 11:31+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 41',
#    'callSign': 'RYR89XB',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QES', 'modeS': '4D23FB', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-06 08:15Z',
#      'local': '2024-11-06 08:15+00:00'},
#     'revisedTime': {'utc': '2024-11-06 09:11Z',
#      'local': '2024-11-06 09:11+00:00'},
#     'runwayTime': {'utc': '2024-11-06 09:13Z',
#      'local': '2024-11-06 09:13+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:10Z',
#      'local': '2024-11-06 11:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:37Z',
#      'local': '2024-11-06 11:37+01:00'},
#     'terminal': '1',
#     'gate': 'Y10',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 8629',
#    'callSign': 'EJU52PM',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJY', 'modeS': '4402AC', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-06 08:15Z',
#      'local': '2024-11-06 08:15+00:00'},
#     'revisedTime': {'utc': '2024-11-06 09:11Z',
#      'local': '2024-11-06 09:11+00:00'},
#     'runwayTime': {'utc': '2024-11-06 09:13Z',
#      'local': '2024-11-06 09:13+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:10Z',
#      'local': '2024-11-06 11:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:37Z',
#      'local': '2024-11-06 11:37+01:00'},
#     'terminal': '1',
#     'gate': 'Y10',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8629',
#    'callSign': 'EJU52PM',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJY', 'modeS': '4402AC', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-11-06 09:10Z',
#      'local': '2024-11-06 10:10+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:18Z',
#      'local': '2024-11-06 10:18+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:28Z',
#      'local': '2024-11-06 10:28+01:00'},
#     'terminal': '5',
#     'checkInDesk': '18-0',
#     'gate': 'D14',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:45Z',
#      'local': '2024-11-06 11:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:39Z',
#      'local': '2024-11-06 11:39+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 4505',
#    'callSign': 'NSZ4505',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RTH',
#     'modeS': '4ACA88',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-11-06 09:15Z',
#      'local': '2024-11-06 11:15+02:00'},
#     'revisedTime': {'utc': '2024-11-06 09:07Z',
#      'local': '2024-11-06 11:07+02:00'},
#     'runwayTime': {'utc': '2024-11-06 09:15Z',
#      'local': '2024-11-06 11:15+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '26',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 11:15Z',
#      'local': '2024-11-06 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:48Z',
#      'local': '2024-11-06 11:48+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1433',
#    'callSign': 'FIN50M',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKG', 'modeS': '461E16', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#      'local': '2024-11-06 12:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:52Z',
#      'local': '2024-11-06 11:52+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1729',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JSM',
#     'modeS': '4BAA6D',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-06 09:45Z',
#      'local': '2024-11-06 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-06 09:45Z',
#      'local': '2024-11-06 10:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 10:55Z',
#      'local': '2024-11-06 11:55+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:55Z',
#      'local': '2024-11-06 11:55+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 180',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIQS', 'modeS': '3C6633', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:17Z',
#      'local': '2024-11-06 10:17+01:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#      'local': '2024-11-06 12:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:56Z',
#      'local': '2024-11-06 11:56+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5082',
#    'callSign': 'EJU86JP',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVG', 'modeS': '440CA9', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-06 08:50Z',
#      'local': '2024-11-06 09:50+01:00'},
#     'runwayTime': {'utc': '2024-11-06 09:17Z',
#      'local': '2024-11-06 10:17+01:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#      'local': '2024-11-06 12:05+01:00'},
#     'revisedTime': {'utc': '2024-11-06 10:56Z',
#      'local': '2024-11-06 11:56+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5082',
#    'callSign': 'EJU86JP',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVG', 'modeS': '440CA9', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}]}

# %% [markdown]
# # Exploring the json

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 03:47Z',
#     'local': '2024-11-06 04:47+01:00'},
#    'revisedTime': {'utc': '2024-11-06 03:47Z',
#     'local': '2024-11-06 04:47+01:00'},
#    'runwayTime': {'utc': '2024-11-06 03:47Z',
#     'local': '2024-11-06 04:47+01:00'},
#    'runway': '14L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 04:33Z',
#     'local': '2024-11-06 05:33+01:00'},
#    'revisedTime': {'utc': '2024-11-06 04:33Z',
#     'local': '2024-11-06 05:33+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'DJ 6228',
#   'callSign': 'SRR6228',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-SRJ', 'modeS': '45CE4A', 'model': 'Boeing 767-200'},
#   'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#  {'departure': {'airport': {'icao': 'ZBAA',
#     'iata': 'PEK',
#     'name': 'Beijing',
#     'timeZone': 'Asia/Shanghai'},
#    'scheduledTime': {'utc': '2024-11-05 19:20Z',
#     'local': '2024-11-06 03:20+08:00'},
#    'revisedTime': {'utc': '2024-11-05 19:30Z',
#     'local': '2024-11-06 03:30+08:00'},
#    'runwayTime': {'utc': '2024-11-05 19:34Z',
#     'local': '2024-11-06 03:34+08:00'},
#    'terminal': '2',
#    'checkInDesk': 'C11-C15',
#    'gate': '14',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 05:40Z',
#     'local': '2024-11-06 06:40+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:00Z',
#     'local': '2024-11-06 06:00+01:00'},
#    'runwayTime': {'utc': '2024-11-06 05:00Z',
#     'local': '2024-11-06 06:00+01:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'HU 489',
#   'callSign': 'CHH489',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'B-1048', 'modeS': '781318', 'model': 'Airbus A330'},
#   'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#  {'departure': {'airport': {'icao': 'OTHH',
#     'iata': 'DOH',
#     'name': 'Doha',
#     'timeZone': 'Asia/Qatar'},
#    'scheduledTime': {'utc': '2024-11-05 23:40Z',
#     'local': '2024-11-06 02:40+03:00'},
#    'revisedTime': {'utc': '2024-11-05 23:39Z',
#     'local': '2024-11-06 02:39+03:00'},
#    'runwayTime': {'utc': '2024-11-06 00:01Z',
#     'local': '2024-11-06 03:01+03:00'},
#    'gate': 'C61',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 05:55Z',
#     'local': '2024-11-06 06:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:37Z',
#     'local': '2024-11-06 06:37+01:00'},
#    'runwayTime': {'utc': '2024-11-06 05:37Z',
#     'local': '2024-11-06 06:37+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'callSign': 'QTR55H',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'A7-BHI', 'modeS': '06A2EC', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 05:39Z',
#     'local': '2024-11-06 06:39+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:39Z',
#     'local': '2024-11-06 06:39+01:00'},
#    'runwayTime': {'utc': '2024-11-06 05:39Z',
#     'local': '2024-11-06 06:39+01:00'},
#    'runway': '14L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 06:24Z',
#     'local': '2024-11-06 07:24+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:24Z',
#     'local': '2024-11-06 07:24+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': '4U 1YX',
#   'callSign': 'GWI1YX',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 05:30Z',
#     'local': '2024-11-06 06:30+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 06:40Z',
#     'local': '2024-11-06 07:40+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 05:20Z',
#     'local': '2024-11-06 06:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:20Z',
#     'local': '2024-11-06 06:20+01:00'},
#    'terminal': '3',
#    'gate': '337',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 06:35Z',
#     'local': '2024-11-06 07:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:38Z',
#     'local': '2024-11-06 07:38+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8001',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'KEWR',
#     'iata': 'EWR',
#     'name': 'Newark',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-11-05 22:50Z',
#     'local': '2024-11-05 17:50-05:00'},
#    'revisedTime': {'utc': '2024-11-05 23:25Z',
#     'local': '2024-11-05 18:25-05:00'},
#    'runwayTime': {'utc': '2024-11-05 23:25Z',
#     'local': '2024-11-05 18:25-05:00'},
#    'terminal': 'C',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 06:55Z',
#     'local': '2024-11-06 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:40Z',
#     'local': '2024-11-06 07:40+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:40Z',
#     'local': '2024-11-06 07:40+01:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B2',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'callSign': 'UAL962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N59053', 'modeS': 'A7A08A', 'model': 'Boeing 767-400'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'OEJN',
#     'iata': 'JED',
#     'name': 'Jeddah',
#     'timeZone': 'Asia/Riyadh'},
#    'scheduledTime': {'utc': '2024-11-06 01:00Z',
#     'local': '2024-11-06 04:00+03:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 08:15+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:43Z',
#     'local': '2024-11-06 07:43+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:43Z',
#     'local': '2024-11-06 07:43+01:00'},
#    'terminal': '1',
#    'gate': 'X06',
#    'baggageBelt': 'A3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'XY 643',
#   'callSign': 'KNE643',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HZ-NS75',
#    'modeS': '717C81',
#    'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 05:45Z',
#     'local': '2024-11-06 06:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:45Z',
#     'local': '2024-11-06 06:45+01:00'},
#    'runwayTime': {'utc': '2024-11-06 05:55Z',
#     'local': '2024-11-06 06:55+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A14',
#    'runway': '25C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 06:55Z',
#     'local': '2024-11-06 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:46Z',
#     'local': '2024-11-06 07:46+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:46Z',
#     'local': '2024-11-06 07:46+01:00'},
#    'terminal': '1',
#    'gate': 'A03',
#    'baggageBelt': 'A4',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'callSign': 'DLH1EL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIRO', 'modeS': '3C664F', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'ELLX',
#     'iata': 'LUX',
#     'name': 'Luxembourg',
#     'timeZone': 'Europe/Luxembourg'},
#    'scheduledTime': {'utc': '2024-11-06 05:30Z',
#     'local': '2024-11-06 06:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 05:27Z',
#     'local': '2024-11-06 06:27+01:00'},
#    'runwayTime': {'utc': '2024-11-06 05:40Z',
#     'local': '2024-11-06 06:40+01:00'},
#    'terminal': 'A',
#    'gate': 'B04',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:00Z',
#     'local': '2024-11-06 08:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:56Z',
#     'local': '2024-11-06 07:56+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:54Z',
#     'local': '2024-11-06 07:54+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B4',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LG 9471',
#   'callSign': 'LGL91B',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LX-LQC',
#    'modeS': '4D00D7',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-11-06 06:10Z',
#     'local': '2024-11-06 07:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:13Z',
#     'local': '2024-11-06 07:13+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:14Z',
#     'local': '2024-11-06 07:14+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F32',
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:25Z',
#     'local': '2024-11-06 08:25+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:05Z',
#     'local': '2024-11-06 08:05+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 223',
#   'callSign': 'AUA223',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LZD', 'modeS': '440605', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 05:30Z',
#     'local': '2024-11-06 06:30+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:05Z',
#     'local': '2024-11-06 08:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:08Z',
#     'local': '2024-11-06 08:08+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DX 121',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#   'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 06:00Z',
#     'local': '2024-11-06 07:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:00Z',
#     'local': '2024-11-06 07:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:10Z',
#     'local': '2024-11-06 08:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:11Z',
#     'local': '2024-11-06 08:11+01:00'},
#    'terminal': '1',
#    'gate': 'B03',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'VL 1928',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGK', 'modeS': '3C48EB', 'model': 'Airbus A319'},
#   'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-11-06 05:05Z',
#     'local': '2024-11-06 07:05+02:00'},
#    'revisedTime': {'utc': '2024-11-06 05:28Z',
#     'local': '2024-11-06 07:28+02:00'},
#    'runwayTime': {'utc': '2024-11-06 05:43Z',
#     'local': '2024-11-06 07:43+02:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '14',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:00Z',
#     'local': '2024-11-06 08:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:13Z',
#     'local': '2024-11-06 08:13+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1431',
#   'callSign': 'FIN3AW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LXI', 'modeS': '461F6A', 'model': 'Airbus A320'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-11-06 06:05Z',
#     'local': '2024-11-06 07:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:19Z',
#     'local': '2024-11-06 07:19+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:19Z',
#     'local': '2024-11-06 07:19+01:00'},
#    'terminal': '2G',
#    'runway': '08L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:55Z',
#     'local': '2024-11-06 08:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:36Z',
#     'local': '2024-11-06 08:36+01:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1434',
#   'callSign': 'AFR1434',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-HBLK', 'modeS': '39856A', 'model': 'Embraer 190'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 06:15Z',
#     'local': '2024-11-06 07:15+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:15Z',
#     'local': '2024-11-06 07:15+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:34Z',
#     'local': '2024-11-06 07:34+01:00'},
#    'checkInDesk': '1',
#    'gate': 'A74',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:45Z',
#     'local': '2024-11-06 08:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:41Z',
#     'local': '2024-11-06 08:41+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 974',
#   'callSign': 'SWR97Y',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JBG', 'modeS': '4B17E4', 'model': 'Airbus A220-100'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 06:45Z',
#     'local': '2024-11-06 07:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:45Z',
#     'local': '2024-11-06 07:45+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:53Z',
#     'local': '2024-11-06 07:53+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A28',
#    'runway': '18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 07:55Z',
#     'local': '2024-11-06 08:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:45Z',
#     'local': '2024-11-06 08:45+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 174',
#   'callSign': 'DLH5CW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AISK', 'modeS': '3C666B', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#     'local': '2024-11-06 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:50Z',
#     'local': '2024-11-06 08:50+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4075',
#   'callSign': 'EJU93LP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICM', 'modeS': '440452', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:30Z',
#     'local': '2024-11-06 07:30+01:00'},
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#     'local': '2024-11-06 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:50Z',
#     'local': '2024-11-06 08:50+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4075',
#   'callSign': 'EJU93LP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICM', 'modeS': '440452', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 07:00Z',
#     'local': '2024-11-06 08:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:00Z',
#     'local': '2024-11-06 08:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:10Z',
#     'local': '2024-11-06 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:09Z',
#     'local': '2024-11-06 09:09+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:09Z',
#     'local': '2024-11-06 09:09+01:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B4',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1930',
#   'callSign': 'DLH2X',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AINQ',
#    'modeS': '3C65D1',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LLBG',
#     'iata': 'TLV',
#     'name': 'Tel Aviv Yafo',
#     'timeZone': 'Asia/Jerusalem'},
#    'scheduledTime': {'utc': '2024-11-06 04:00Z',
#     'local': '2024-11-06 06:00+02:00'},
#    'revisedTime': {'utc': '2024-11-06 04:15Z',
#     'local': '2024-11-06 06:15+02:00'},
#    'runwayTime': {'utc': '2024-11-06 04:15Z',
#     'local': '2024-11-06 06:15+02:00'},
#    'terminal': '3',
#    'runway': '26',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:30Z',
#     'local': '2024-11-06 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:12Z',
#     'local': '2024-11-06 09:12+01:00'},
#    'terminal': '1',
#    'gate': 'X19',
#    'baggageBelt': 'A3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LY 2371',
#   'callSign': 'ELY2371',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '4X-EKH', 'modeS': '73806D', 'model': 'Boeing 737'},
#   'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-11-06 07:05Z',
#     'local': '2024-11-06 08:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:07Z',
#     'local': '2024-11-06 08:07+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 08:15+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'D84',
#    'runway': '24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:25Z',
#     'local': '2024-11-06 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:15Z',
#     'local': '2024-11-06 09:15+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1771',
#   'callSign': 'KLM1771',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:26Z',
#     'local': '2024-11-06 09:26+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:26Z',
#     'local': '2024-11-06 09:26+01:00'},
#    'terminal': '1',
#    'gate': 'X03',
#    'baggageBelt': 'A3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1721',
#   'callSign': 'THY4CM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-LPA', 'modeS': '4BB201', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-11-06 07:30Z',
#     'local': '2024-11-06 08:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:30Z',
#     'local': '2024-11-06 08:30+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:48Z',
#     'local': '2024-11-06 08:48+01:00'},
#    'terminal': 'erminal3',
#    'gate': 'B6',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:30Z',
#     'local': '2024-11-06 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:29Z',
#     'local': '2024-11-06 09:29+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:29Z',
#     'local': '2024-11-06 09:29+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'SK 1673',
#   'callSign': 'SAS1673',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-DOX',
#    'modeS': '4A91F8',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-11-06 05:00Z',
#     'local': '2024-11-06 08:00+03:00'},
#    'revisedTime': {'utc': '2024-11-06 05:00Z',
#     'local': '2024-11-06 08:00+03:00'},
#    'terminal': '2',
#    'checkInDesk': '238-240',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:20Z',
#     'local': '2024-11-06 09:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:32Z',
#     'local': '2024-11-06 09:32+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:31Z',
#     'local': '2024-11-06 09:31+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A2',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FH 1281',
#   'callSign': 'FHY1281',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-FBR', 'modeS': '4B9852', 'model': 'Airbus A320'},
#   'airline': {'name': 'Freebird', 'iata': 'FH', 'icao': 'FHY'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 07:20Z',
#     'local': '2024-11-06 08:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 08:15+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:22Z',
#     'local': '2024-11-06 08:22+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A84',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:34Z',
#     'local': '2024-11-06 09:34+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5188',
#   'callSign': 'EJU53ZL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 07:20Z',
#     'local': '2024-11-06 08:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 08:15+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:22Z',
#     'local': '2024-11-06 08:22+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A84',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:34Z',
#     'local': '2024-11-06 09:34+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5188',
#   'callSign': 'EJU53ZL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EIDW',
#     'iata': 'DUB',
#     'name': 'Dublin',
#     'timeZone': 'Europe/Dublin'},
#    'scheduledTime': {'utc': '2024-11-06 06:20Z',
#     'local': '2024-11-06 06:20+00:00'},
#    'revisedTime': {'utc': '2024-11-06 06:20Z',
#     'local': '2024-11-06 06:20+00:00'},
#    'runwayTime': {'utc': '2024-11-06 06:44Z',
#     'local': '2024-11-06 06:44+00:00'},
#    'terminal': '2',
#    'checkInDesk': '29-56',
#    'gate': '418',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:38Z',
#     'local': '2024-11-06 09:38+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:37Z',
#     'local': '2024-11-06 09:37+01:00'},
#    'terminal': '1',
#    'gate': 'X10',
#    'baggageBelt': 'A1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EI 332',
#   'callSign': 'EIN3JE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-NSA', 'modeS': '4CAD7A', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 07:30Z',
#     'local': '2024-11-06 08:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:30Z',
#     'local': '2024-11-06 08:30+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:42Z',
#     'local': '2024-11-06 08:42+01:00'},
#    'checkInDesk': '1',
#    'gate': 'A75',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:55Z',
#     'local': '2024-11-06 09:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:47Z',
#     'local': '2024-11-06 09:47+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'B2',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 976',
#   'callSign': 'SWR2HD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JVO', 'modeS': '4B19F4', 'model': 'Embraer 190'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 07:45Z',
#     'local': '2024-11-06 08:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 07:45Z',
#     'local': '2024-11-06 08:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A15',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:55Z',
#     'local': '2024-11-06 09:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 176',
#   'callSign': 'DLH9KK',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AINM',
#    'modeS': '3C65CD',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-06 07:10Z',
#     'local': '2024-11-06 07:10+00:00'},
#    'revisedTime': {'utc': '2024-11-06 07:24Z',
#     'local': '2024-11-06 07:24+00:00'},
#    'runwayTime': {'utc': '2024-11-06 07:25Z',
#     'local': '2024-11-06 07:25+00:00'},
#    'terminal': '5',
#    'checkInDesk': 'D',
#    'runway': '27L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:05Z',
#     'local': '2024-11-06 10:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:53Z',
#     'local': '2024-11-06 09:53+01:00'},
#    'terminal': '1',
#    'gate': 'X06',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 990',
#   'callSign': 'BAW990G',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EUPK', 'modeS': '40087A', 'model': 'Airbus A319'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LGAV',
#     'iata': 'ATH',
#     'name': 'Athens',
#     'timeZone': 'Europe/Athens'},
#    'scheduledTime': {'utc': '2024-11-06 05:35Z',
#     'local': '2024-11-06 07:35+02:00'},
#    'revisedTime': {'utc': '2024-11-06 06:29Z',
#     'local': '2024-11-06 08:29+02:00'},
#    'terminal': 'I',
#    'checkInDesk': '11---15',
#    'gate': 'A03',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:54Z',
#     'local': '2024-11-06 09:54+01:00'},
#    'terminal': '1',
#    'gate': 'Y03',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'TV 720',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#   'airline': {'name': 'Tibet', 'iata': 'TV', 'icao': 'TBA'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-06 06:15Z',
#     'local': '2024-11-06 07:15+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:22Z',
#     'local': '2024-11-06 07:22+01:00'},
#    'runwayTime': {'utc': '2024-11-06 06:40Z',
#     'local': '2024-11-06 07:40+01:00'},
#    'terminal': '1',
#    'checkInDesk': '501-514',
#    'gate': 'A16',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:00Z',
#     'local': '2024-11-06 10:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:57Z',
#     'local': '2024-11-06 09:57+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'VY 1882',
#   'callSign': 'VLG1882',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-NYC', 'modeS': '34734F', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 08:00Z',
#     'local': '2024-11-06 09:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:00Z',
#     'local': '2024-11-06 09:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:10Z',
#     'local': '2024-11-06 10:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:01Z',
#     'local': '2024-11-06 10:01+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1934',
#   'callSign': 'DLH5T',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIUD',
#    'modeS': '3C66A4',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EGSS',
#     'iata': 'STN',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-06 07:25Z',
#     'local': '2024-11-06 07:25+00:00'},
#    'revisedTime': {'utc': '2024-11-06 07:29Z',
#     'local': '2024-11-06 07:29+00:00'},
#    'runwayTime': {'utc': '2024-11-06 07:39Z',
#     'local': '2024-11-06 07:39+00:00'},
#    'terminal': '1',
#    'gate': '42',
#    'runway': '22',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:05Z',
#     'local': '2024-11-06 10:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:04Z',
#     'local': '2024-11-06 10:04+01:00'},
#    'terminal': '2',
#    'gate': 'Z38',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 145',
#   'callSign': 'RYR4DA',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QBO', 'modeS': '4D221D', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 08:05Z',
#     'local': '2024-11-06 09:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:00Z',
#     'local': '2024-11-06 09:00+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:07Z',
#     'local': '2024-11-06 09:07+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A85',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#     'local': '2024-11-06 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:12Z',
#     'local': '2024-11-06 10:12+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 4406',
#   'callSign': 'EWG44U',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-06 08:05Z',
#     'local': '2024-11-06 09:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:00Z',
#     'local': '2024-11-06 09:00+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:07Z',
#     'local': '2024-11-06 09:07+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A85',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#     'local': '2024-11-06 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:12Z',
#     'local': '2024-11-06 10:12+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:13Z',
#     'local': '2024-11-06 10:13+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8761',
#   'callSign': 'EWG44U',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EIDW',
#     'iata': 'DUB',
#     'name': 'Dublin',
#     'timeZone': 'Europe/Dublin'},
#    'scheduledTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 07:15+00:00'},
#    'revisedTime': {'utc': '2024-11-06 07:15Z',
#     'local': '2024-11-06 07:15+00:00'},
#    'runwayTime': {'utc': '2024-11-06 07:24Z',
#     'local': '2024-11-06 07:24+00:00'},
#    'terminal': '1',
#    'checkInDesk': '1204-1319',
#    'gate': '107',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:25Z',
#     'local': '2024-11-06 10:25+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:16Z',
#     'local': '2024-11-06 10:16+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:15Z',
#     'local': '2024-11-06 10:15+01:00'},
#    'terminal': '2',
#    'gate': 'Z44',
#    'baggageBelt': 'C3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3669',
#   'callSign': 'RYR68RF',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EKW', 'modeS': '4CA815', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LIPB',
#     'iata': 'BZO',
#     'name': 'Bolzano',
#     'timeZone': 'Europe/Rome'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:20Z',
#     'local': '2024-11-06 10:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:20Z',
#     'local': '2024-11-06 10:20+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:20Z',
#     'local': '2024-11-06 10:20+01:00'},
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'SWU 1950',
#   'callSign': 'SWU1950',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-BEL',
#    'modeS': '4D2320',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'SWU'}},
#  {'departure': {'airport': {'icao': 'LIPB',
#     'iata': 'BZO',
#     'name': 'Bolzano',
#     'timeZone': 'Europe/Rome'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:40Z',
#     'local': '2024-11-06 10:40+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:21Z',
#     'local': '2024-11-06 10:21+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'BQ 1950',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-BEL',
#    'modeS': '4D2320',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'BQ'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-11-06 08:20Z',
#     'local': '2024-11-06 09:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:27Z',
#     'local': '2024-11-06 09:27+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:28Z',
#     'local': '2024-11-06 09:28+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F25',
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:35Z',
#     'local': '2024-11-06 10:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:23Z',
#     'local': '2024-11-06 10:23+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:22Z',
#     'local': '2024-11-06 10:22+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 225',
#   'callSign': 'AUA225S',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LWF', 'modeS': '440822', 'model': 'Embraer 195'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LHBP',
#     'iata': 'BUD',
#     'name': 'Budapest',
#     'timeZone': 'Europe/Budapest'},
#    'scheduledTime': {'utc': '2024-11-06 07:55Z',
#     'local': '2024-11-06 08:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:16Z',
#     'local': '2024-11-06 09:16+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:17Z',
#     'local': '2024-11-06 09:17+01:00'},
#    'terminal': '2B',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:25Z',
#     'local': '2024-11-06 10:25+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:26Z',
#     'local': '2024-11-06 10:26+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C1',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 197',
#   'callSign': 'RYR81UJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VUE', 'modeS': '4D2303', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'OEJN',
#     'iata': 'JED',
#     'name': 'Jeddah',
#     'timeZone': 'Asia/Riyadh'},
#    'scheduledTime': {'utc': '2024-11-06 03:30Z',
#     'local': '2024-11-06 06:30+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:35Z',
#     'local': '2024-11-06 10:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:30Z',
#     'local': '2024-11-06 10:30+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 1159',
#   'callSign': 'EWG1159',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENC', 'modeS': '3C55C3', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EPWA',
#     'iata': 'WAW',
#     'name': 'Warsaw',
#     'timeZone': 'Europe/Warsaw'},
#    'scheduledTime': {'utc': '2024-11-06 08:20Z',
#     'local': '2024-11-06 09:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:39Z',
#     'local': '2024-11-06 09:39+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:39Z',
#     'local': '2024-11-06 09:39+01:00'},
#    'runway': '33',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:45Z',
#     'local': '2024-11-06 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:32Z',
#     'local': '2024-11-06 10:32+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LO 387',
#   'callSign': 'LOT7AE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SP-LIA', 'modeS': '48AD00', 'model': 'Embraer 175'},
#   'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#  {'departure': {'airport': {'icao': 'LEMD',
#     'iata': 'MAD',
#     'name': 'Madrid',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-06 06:50Z',
#     'local': '2024-11-06 07:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:58Z',
#     'local': '2024-11-06 07:58+01:00'},
#    'runwayTime': {'utc': '2024-11-06 07:11Z',
#     'local': '2024-11-06 08:11+01:00'},
#    'terminal': '4',
#    'checkInDesk': '850-859',
#    'gate': 'J40',
#    'runway': '36R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:55Z',
#     'local': '2024-11-06 10:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:41Z',
#     'local': '2024-11-06 10:41+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'I2 1801',
#   'callSign': 'IBS18JP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-OCC', 'modeS': '347553', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Düsseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 07:40Z',
#     'local': '2024-11-06 08:40+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:38Z',
#     'local': '2024-11-06 09:38+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:52Z',
#     'local': '2024-11-06 09:52+01:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:46Z',
#     'local': '2024-11-06 10:46+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8041',
#   'callSign': 'GWI2R',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LTFJ',
#     'iata': 'SAW',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-11-06 06:50Z',
#     'local': '2024-11-06 09:50+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:50Z',
#     'local': '2024-11-06 10:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:49Z',
#     'local': '2024-11-06 10:49+01:00'},
#    'terminal': '1',
#    'gate': 'X10',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 977',
#   'callSign': 'PGT1FM',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-RDK', 'modeS': '4BC88B', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'LEMD',
#     'iata': 'MAD',
#     'name': 'Madrid',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-06 06:50Z',
#     'local': '2024-11-06 07:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 06:58Z',
#     'local': '2024-11-06 07:58+01:00'},
#    'terminal': '4',
#    'checkInDesk': '850-859',
#    'gate': 'J40',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:55Z',
#     'local': '2024-11-06 10:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:55Z',
#     'local': '2024-11-06 10:55+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'IB 1801',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A321-100'},
#   'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
# ...
#     'local': '2024-11-06 11:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:05Z',
#     'local': '2024-11-06 11:05+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1734',
#   'callSign': 'AFR66CF',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-GKXH', 'modeS': '392AE7', 'model': 'Airbus A320'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-11-06 08:30Z',
#     'local': '2024-11-06 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:41Z',
#     'local': '2024-11-06 09:41+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:53Z',
#     'local': '2024-11-06 09:53+01:00'},
#    'terminal': '5',
#    'checkInDesk': '71-80',
#    'gate': 'E4',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:05Z',
#     'local': '2024-11-06 11:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:06Z',
#     'local': '2024-11-06 11:06+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'SK 2677',
#   'callSign': 'SAS2677',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-SIN', 'modeS': '4CAD41', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#  {'departure': {'airport': {'icao': 'EBBR',
#     'iata': 'BRU',
#     'name': 'Brussels',
#     'timeZone': 'Europe/Brussels'},
#    'scheduledTime': {'utc': '2024-11-06 08:40Z',
#     'local': '2024-11-06 09:40+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:05Z',
#     'local': '2024-11-06 10:05+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:06Z',
#     'local': '2024-11-06 10:06+01:00'},
#    'checkInDesk': '05',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:05Z',
#     'local': '2024-11-06 11:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:06Z',
#     'local': '2024-11-06 11:06+01:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'SN 2581',
#   'callSign': 'BEL8CE',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#   'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-06 08:25Z',
#     'local': '2024-11-06 08:25+00:00'},
#    'revisedTime': {'utc': '2024-11-06 08:45Z',
#     'local': '2024-11-06 08:45+00:00'},
#    'runwayTime': {'utc': '2024-11-06 08:46Z',
#     'local': '2024-11-06 08:46+00:00'},
#    'terminal': '5',
#    'checkInDesk': 'D',
#    'runway': '27L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:20Z',
#     'local': '2024-11-06 11:20+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:06Z',
#     'local': '2024-11-06 11:06+01:00'},
#    'terminal': '1',
#    'gate': 'Y07',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 992',
#   'callSign': 'BAW992G',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-NEOW', 'modeS': '4077E0', 'model': 'Airbus A321'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 09:20Z',
#     'local': '2024-11-06 10:20+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:30Z',
#     'local': '2024-11-06 11:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:15Z',
#     'local': '2024-11-06 11:15+01:00'},
#    'terminal': '1',
#    'gate': 'B02',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 4',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWL', 'modeS': '3C5EEC', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 08:45Z',
#     'local': '2024-11-06 09:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:05Z',
#     'local': '2024-11-06 10:05+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:31Z',
#     'local': '2024-11-06 10:31+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A18',
#    'runway': '25C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 09:55Z',
#     'local': '2024-11-06 10:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:18Z',
#     'local': '2024-11-06 11:18+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 178',
#   'callSign': 'DLH178',
#   'status': 'Delayed',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIWA', 'modeS': '3C66E1', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LBSF',
#     'iata': 'SOF',
#     'name': 'Sofia',
#     'timeZone': 'Europe/Sofia'},
#    'scheduledTime': {'utc': '2024-11-06 08:20Z',
#     'local': '2024-11-06 10:20+02:00'},
#    'revisedTime': {'utc': '2024-11-06 08:37Z',
#     'local': '2024-11-06 10:37+02:00'},
#    'runwayTime': {'utc': '2024-11-06 08:37Z',
#     'local': '2024-11-06 10:37+02:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:30Z',
#     'local': '2024-11-06 11:30+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:25Z',
#     'local': '2024-11-06 11:25+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'FB 319',
#   'callSign': 'LZB319',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LZ-LIS', 'modeS': '452163', 'model': 'Airbus A220-100'},
#   'airline': {'name': 'Bulgaria Air', 'iata': 'FB', 'icao': 'LZB'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 09:00Z',
#     'local': '2024-11-06 10:00+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:00Z',
#     'local': '2024-11-06 10:00+01:00'},
#    'terminal': '3',
#    'gate': '173',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:15Z',
#     'local': '2024-11-06 11:15+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:28Z',
#     'local': '2024-11-06 11:28+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8003',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:35Z',
#     'local': '2024-11-06 09:35+01:00'},
#    'runwayTime': {'utc': '2024-11-06 08:55Z',
#     'local': '2024-11-06 09:55+01:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:45Z',
#     'local': '2024-11-06 11:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:31Z',
#     'local': '2024-11-06 11:31+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 41',
#   'callSign': 'RYR89XB',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QES', 'modeS': '4D23FB', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-06 08:15Z',
#     'local': '2024-11-06 08:15+00:00'},
#    'revisedTime': {'utc': '2024-11-06 09:11Z',
#     'local': '2024-11-06 09:11+00:00'},
#    'runwayTime': {'utc': '2024-11-06 09:13Z',
#     'local': '2024-11-06 09:13+00:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:10Z',
#     'local': '2024-11-06 11:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:37Z',
#     'local': '2024-11-06 11:37+01:00'},
#    'terminal': '1',
#    'gate': 'Y10',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 8629',
#   'callSign': 'EJU52PM',
#   'status': 'Delayed',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IJY', 'modeS': '4402AC', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-06 08:15Z',
#     'local': '2024-11-06 08:15+00:00'},
#    'revisedTime': {'utc': '2024-11-06 09:11Z',
#     'local': '2024-11-06 09:11+00:00'},
#    'runwayTime': {'utc': '2024-11-06 09:13Z',
#     'local': '2024-11-06 09:13+00:00'},
#    'terminal': 'N',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:10Z',
#     'local': '2024-11-06 11:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:37Z',
#     'local': '2024-11-06 11:37+01:00'},
#    'terminal': '1',
#    'gate': 'Y10',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 8629',
#   'callSign': 'EJU52PM',
#   'status': 'Delayed',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IJY', 'modeS': '4402AC', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-11-06 09:10Z',
#     'local': '2024-11-06 10:10+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:18Z',
#     'local': '2024-11-06 10:18+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:28Z',
#     'local': '2024-11-06 10:28+01:00'},
#    'terminal': '5',
#    'checkInDesk': '18-0',
#    'gate': 'D14',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:45Z',
#     'local': '2024-11-06 11:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:39Z',
#     'local': '2024-11-06 11:39+01:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'D8 4505',
#   'callSign': 'NSZ4505',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-RTH',
#    'modeS': '4ACA88',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-11-06 09:15Z',
#     'local': '2024-11-06 11:15+02:00'},
#    'revisedTime': {'utc': '2024-11-06 09:07Z',
#     'local': '2024-11-06 11:07+02:00'},
#    'runwayTime': {'utc': '2024-11-06 09:15Z',
#     'local': '2024-11-06 11:15+02:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '26',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 11:15Z',
#     'local': '2024-11-06 12:15+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:48Z',
#     'local': '2024-11-06 11:48+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1433',
#   'callSign': 'FIN50M',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LKG', 'modeS': '461E16', 'model': 'Embraer 190'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#     'local': '2024-11-06 12:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:52Z',
#     'local': '2024-11-06 11:52+01:00'},
#    'terminal': '1',
#    'gate': 'X06',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1729',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-JSM',
#    'modeS': '4BAA6D',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-06 09:45Z',
#     'local': '2024-11-06 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-06 09:45Z',
#     'local': '2024-11-06 10:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 10:55Z',
#     'local': '2024-11-06 11:55+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:55Z',
#     'local': '2024-11-06 11:55+01:00'},
#    'terminal': '1',
#    'gate': 'A03',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 180',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIQS', 'modeS': '3C6633', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:17Z',
#     'local': '2024-11-06 10:17+01:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#     'local': '2024-11-06 12:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:56Z',
#     'local': '2024-11-06 11:56+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5082',
#   'callSign': 'EJU86JP',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVG', 'modeS': '440CA9', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-06 08:50Z',
#     'local': '2024-11-06 09:50+01:00'},
#    'runwayTime': {'utc': '2024-11-06 09:17Z',
#     'local': '2024-11-06 10:17+01:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-06 11:05Z',
#     'local': '2024-11-06 12:05+01:00'},
#    'revisedTime': {'utc': '2024-11-06 10:56Z',
#     'local': '2024-11-06 11:56+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5082',
#   'callSign': 'EJU86JP',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVG', 'modeS': '440CA9', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}]

# %% [markdown]
# The square brackets at the beginning of `flights_json` indicate that it represents a list-like structure. Since we're dealing with a list, we can iterate through its elements to access and process the data. Let's start by examining the first element in the list.

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'EDDK',
#    'iata': 'CGN',
#    'name': 'Cologne',
#    'timeZone': 'Europe/Berlin'},
#   'scheduledTime': {'utc': '2024-11-06 03:47Z',
#    'local': '2024-11-06 04:47+01:00'},
#   'revisedTime': {'utc': '2024-11-06 03:47Z',
#    'local': '2024-11-06 04:47+01:00'},
#   'runwayTime': {'utc': '2024-11-06 03:47Z',
#    'local': '2024-11-06 04:47+01:00'},
#   'runway': '14L',
#   'quality': ['Basic', 'Live']},
#  'arrival': {'scheduledTime': {'utc': '2024-11-06 04:33Z',
#    'local': '2024-11-06 05:33+01:00'},
#   'revisedTime': {'utc': '2024-11-06 04:33Z',
#    'local': '2024-11-06 05:33+01:00'},
#   'quality': ['Basic', 'Live']},
#  'number': 'DJ 6228',
#  'callSign': 'SRR6228',
#  'status': 'Approaching',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'OY-SRJ', 'modeS': '45CE4A', 'model': 'Boeing 767-200'},
#  'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}}

# %%
flights_json["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %% [markdown]
# Looking at the first element of the json and the available keys, we can select the information we think would be important for our dataframe.
# - Departure airport icao
# - scheduled arrival time, local
# - flight number

# %% [markdown]
# # Using for loops

# %% [markdown]
# ## Making the DataFrame

# %%
flight_items = []

for item in flights_json["arrivals"]:
  flight_item = {
      "arrival_airport_icao": icao,
      "departure_airport_icao": item["departure"]["airport"].get("icao", None),
      "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
      "flight_number": item.get("number", None)
  }

  flight_items.append(flight_item)

flights_df = pd.DataFrame(flight_items)

flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao  scheduled_arrival_time  \
# 0                 EDDB                   EDDK  2024-11-06 05:33+01:00
# 1                 EDDB                   ZBAA  2024-11-06 06:40+01:00
# 2                 EDDB                   OTHH  2024-11-06 06:55+01:00
# 3                 EDDB                   EDDK  2024-11-06 07:24+01:00
# 4                 EDDB                   EDDK  2024-11-06 07:40+01:00
#
#   flight_number
# 0       DJ 6228
# 1        HU 489
# 2         QR 79
# 3        4U 1YX
# 4          EW 2

# %% [markdown]
# Let's get rid of the `+01:00` from `scheduled_arrival_time`.

# %%
flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                 EDDB                   EDDK       2024-11-06 05:33
# 1                 EDDB                   ZBAA       2024-11-06 06:40
# 2                 EDDB                   OTHH       2024-11-06 06:55
# 3                 EDDB                   EDDK       2024-11-06 07:24
# 4                 EDDB                   EDDK       2024-11-06 07:40
#
#   flight_number
# 0       DJ 6228
# 1        HU 489
# 2         QR 79
# 3        4U 1YX
# 4          EW 2

# %% [markdown]
# While string slicing provides a quick solution to correcting the `scheduled_arrival_time` column, it's not the most robust approach. This is because it assumes that every cell in the column has the `+01:00` time zone offset. If there are cells without this offset, slicing would remove part of the time value, leading to inaccurate results.
#
# A more robust solution would involve using the `re.sub()` function from the re module. Feel free to look into this if you have extra time and are curious.

# %% [markdown]
# ## Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = os.getenv('aerodatabox_api_key')

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': api_key
          }

      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %%
icao_list = ["EDDB", "EDDF"]

get_flight_data(icao_list)
# Out:
#      arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                    EDDB                   OTHH    2024-11-07 06:55:00
# 1                    EDDB                   LIMC    2024-11-07 07:30:00
# 2                    EDDB                   LBSF    2024-11-07 07:30:00
# 3                    EDDB                   EDDS    2024-11-07 07:35:00
# 4                    EDDB                   LFSB    2024-11-07 07:40:00
# ...                   ...                    ...                    ...
# 2262                 EDDF                   LEMD    2024-11-07 22:35:00
# 2263                 EDDF                   LPPT    2024-11-07 22:40:00
# 2264                 EDDF                   LPPT    2024-11-07 22:40:00
# 2265                 EDDF                   LPPT    2024-11-07 22:40:00
# 2266                 EDDF                   LPPT    2024-11-07 22:40:00
#
#      flight_number   data_retrieved_at
# 0            QR 79 2024-11-06 13:08:31
# 1             FR 9 2024-11-06 13:08:31
# 2          FR 1149 2024-11-06 13:08:31
# 3          EW 2000 2024-11-06 13:08:31
# 4          U2 1185 2024-11-06 13:08:31
# ...            ...                 ...
# 2262       VY 5520 2024-11-06 13:08:33
# 2263       S4 8762 2024-11-06 13:08:33
# 2264        TP 574 2024-11-06 13:08:33
# 2265       AC 2660 2024-11-06 13:08:33
# 2266       LH 6957 2024-11-06 13:08:33
#
# [2267 rows x 5 columns]

# %% [markdown]
# Your flight function can now be incorporated with your other functions to send and receive data from your SQL database.

# %% [markdown]
# # Using json_normalize

# %%
def tomorrows_flight_arrivals(icao_list):

    api_key = os.getenv('aerodatabox_api_key')

    berlin_timezone = timezone('Europe/Berlin')
    today = datetime.now(berlin_timezone).date()
    tomorrow = (today + timedelta(days=1))

    list_for_arrivals_df = []

    for icao in icao_list:

        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"direction":"Arrival","withCancelled":"false"}

            headers = {
                "X-RapidAPI-Key": api_key,
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.request("GET", url, headers=headers, params=querystring)
            flights_resp = response.json()

            arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "airline.name", "movement.scheduledTime.local", "movement.terminal", "movement.airport.name", "movement.airport.icao"]]
            arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "airline.name": "airline", "movement.scheduledTime.local": "arrival_time", "movement.terminal": "arrival_terminal", "movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
            arrivals_df["arrival_airport_icao"] = icao
            arrivals_df["data_retrieved_on"] = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")
            arrivals_df = arrivals_df[["arrival_airport_icao", "flight_number", "airline", "arrival_time", "arrival_terminal", "departure_city", "departure_airport_icao", "data_retrieved_on"]]

            # fixing arrival_time
            arrivals_df["arrival_time"] = arrivals_df["arrival_time"].str.split("+").str[0]

            list_for_arrivals_df.append(arrivals_df)

    return pd.concat(list_for_arrivals_df, ignore_index=True)

# %%
icao_list = ["EDDF", "EDDB"]

tomorrows_flight_arrivals(icao_list)
# Out:
#      arrival_airport_icao flight_number         airline      arrival_time  \
# 0                    EDDF       LH 4305       Lufthansa  2024-11-07 05:20
# 1                    EDDF       OS 8500        Austrian  2024-11-07 05:20
# 2                    EDDF       LX 9349           SWISS  2024-11-07 05:20
# 3                    EDDF       SN 7207        Brussels  2024-11-07 05:20
# 4                    EDDF       OS 7316        Austrian  2024-11-07 05:20
# ...                   ...           ...             ...               ...
# 2262                 EDDB       FR 1145         Ryanair  2024-11-07 22:55
# 2263                 EDDB       EW 8983       Eurowings  2024-11-07 23:10
# 2264                 EDDB       IB 1809          Iberia  2024-11-07 23:10
# 2265                 EDDB       I2 1809  Iberia Express  2024-11-07 23:10
# 2266                 EDDB       EW 1151       Eurowings  2024-11-07 23:20
#
#      arrival_terminal  departure_city departure_airport_icao  \
# 0                   1  Victoria Falls                   FVFA
# 1                   1  Victoria Falls                   FVFA
# 2                   1  Victoria Falls                   FVFA
# 3                   1         Jo'anna                   FAOR
# 4                   1         Jo'anna                   FAOR
# ...               ...             ...                    ...
# 2262                2      Manchester                   EGCC
# 2263                1        Hurghada                   HEGN
# 2264                1          Madrid                   LEMD
# 2265                1          Madrid                   LEMD
# 2266                1           Dubai                   OMDB
#
#         data_retrieved_on
# 0     2024-11-06 13:08:33
# 1     2024-11-06 13:08:33
# 2     2024-11-06 13:08:33
# 3     2024-11-06 13:08:33
# 4     2024-11-06 13:08:33
# ...                   ...
# 2262  2024-11-06 13:08:35
# 2263  2024-11-06 13:08:35
# 2264  2024-11-06 13:08:35
# 2265  2024-11-06 13:08:35
# 2266  2024-11-06 13:08:35
#
# [2267 rows x 8 columns]
