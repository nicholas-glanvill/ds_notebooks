# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone
from dotenv import load_dotenv
import os

# using colab secrets to store our passwords and keys

# %% [markdown]
# # Making the API call and viewing the json

# %%
load_dotenv()  # Load environment variables from .env file

api_key = os.getenv('aerodatabox_api_key')
icao = "EDDB"
date = datetime.now().date()
time_1 = "00:00"
time_2 = "11:59"

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{date}T{time_1}/{date}T{time_2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET",
                            url,
                            headers = headers,
                            params = querystring)

flights_json = response.json()

flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 04:30Z',
#      'local': '2024-11-05 05:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 04:30Z',
#      'local': '2024-11-05 05:30+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'DJ 6228',
#    'callSign': 'SRR6228',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#    'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#   {'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2024-11-04 23:40Z',
#      'local': '2024-11-05 02:40+03:00'},
#     'revisedTime': {'utc': '2024-11-04 23:39Z',
#      'local': '2024-11-05 02:39+03:00'},
#     'runwayTime': {'utc': '2024-11-04 23:53Z',
#      'local': '2024-11-05 02:53+03:00'},
#     'gate': 'C41',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 05:55Z',
#      'local': '2024-11-05 06:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:39Z',
#      'local': '2024-11-05 06:39+01:00'},
#     'runwayTime': {'utc': '2024-11-05 05:38Z',
#      'local': '2024-11-05 06:38+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A2',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'callSign': 'QTR55H',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-BHG', 'modeS': '06A2EA', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 06:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:11Z',
#      'local': '2024-11-05 06:11+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '78',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#      'local': '2024-11-05 07:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:12Z',
#      'local': '2024-11-05 07:12+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:11Z',
#      'local': '2024-11-05 07:11+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1185',
#    'callSign': 'EZS53DP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JXU',
#     'modeS': '4B1A2E',
#     'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 06:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:11Z',
#      'local': '2024-11-05 06:11+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '78',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#      'local': '2024-11-05 07:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:12Z',
#      'local': '2024-11-05 07:12+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:11Z',
#      'local': '2024-11-05 07:11+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1185',
#    'callSign': 'EZS53DP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JXU',
#     'modeS': '4B1A2E',
#     'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 05:30Z',
#      'local': '2024-11-05 06:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:30Z',
#      'local': '2024-11-05 06:30+01:00'},
#     'terminal': '3',
#     'gate': '321',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 07:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:20Z',
#      'local': '2024-11-05 07:20+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2000',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 05:30Z',
#      'local': '2024-11-05 06:30+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#      'local': '2024-11-05 07:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:25Z',
#      'local': '2024-11-05 07:25+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AKNV', 'modeS': '3C6DD6', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Düsseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 05:40Z',
#      'local': '2024-11-05 06:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:38Z',
#      'local': '2024-11-05 06:38+01:00'},
#     'runwayTime': {'utc': '2024-11-05 05:45Z',
#      'local': '2024-11-05 06:45+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#      'local': '2024-11-05 07:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:30Z',
#      'local': '2024-11-05 07:30+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9040',
#    'callSign': 'GWI6LZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWD', 'modeS': '4D2416', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-11-05 05:15Z',
#      'local': '2024-11-05 06:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:09Z',
#      'local': '2024-11-05 06:09+01:00'},
#     'runwayTime': {'utc': '2024-11-05 05:19Z',
#      'local': '2024-11-05 06:19+01:00'},
#     'terminal': '5',
#     'checkInDesk': '22-24',
#     'gate': 'C37',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#      'local': '2024-11-05 07:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:35Z',
#      'local': '2024-11-05 07:35+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5344',
#    'callSign': 'EWG6CA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWE', 'modeS': '4D2417', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-11-05 05:15Z',
#      'local': '2024-11-05 06:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:09Z',
#      'local': '2024-11-05 06:09+01:00'},
#     'runwayTime': {'utc': '2024-11-05 05:19Z',
#      'local': '2024-11-05 06:19+01:00'},
#     'terminal': '5',
#     'checkInDesk': '22-24',
#     'gate': 'C37',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#      'local': '2024-11-05 07:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:35Z',
#      'local': '2024-11-05 07:35+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4600',
#    'callSign': 'EWG6CA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWE', 'modeS': '4D2417', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 05:45Z',
#      'local': '2024-11-05 06:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 05:45Z',
#      'local': '2024-11-05 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:37Z',
#      'local': '2024-11-05 07:37+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISK', 'modeS': '3C666B', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-11-05 05:05Z',
#      'local': '2024-11-05 07:05+02:00'},
#     'revisedTime': {'utc': '2024-11-05 05:04Z',
#      'local': '2024-11-05 07:04+02:00'},
#     'runwayTime': {'utc': '2024-11-05 05:15Z',
#      'local': '2024-11-05 07:15+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '36A',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:00Z',
#      'local': '2024-11-05 08:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:49Z',
#      'local': '2024-11-05 07:49+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:49Z',
#      'local': '2024-11-05 07:49+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LXI', 'modeS': '461F6A', 'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'revisedTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'terminal': 'C',
#     'gate': 'C2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:52Z',
#      'local': '2024-11-05 07:52+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'JU 7659',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSG',
#     'modeS': '502CD0',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'JU'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'revisedTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'terminal': 'C',
#     'gate': 'C2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:52Z',
#      'local': '2024-11-05 07:52+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:51Z',
#      'local': '2024-11-05 07:51+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'B3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 211',
#    'callSign': 'BTI74A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSG',
#     'modeS': '502CD0',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#   {'departure': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'revisedTime': {'utc': '2024-11-05 05:10Z',
#      'local': '2024-11-05 07:10+02:00'},
#     'terminal': 'C',
#     'gate': 'C2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:52Z',
#      'local': '2024-11-05 07:52+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 3219',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSG',
#     'modeS': '502CD0',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 05:30Z',
#      'local': '2024-11-05 06:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:05Z',
#      'local': '2024-11-05 08:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:54Z',
#      'local': '2024-11-05 07:54+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 121',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-11-04 22:50Z',
#      'local': '2024-11-04 17:50-05:00'},
#     'revisedTime': {'utc': '2024-11-04 23:25Z',
#      'local': '2024-11-04 18:25-05:00'},
#     'runwayTime': {'utc': '2024-11-04 23:25Z',
#      'local': '2024-11-04 18:25-05:00'},
#     'terminal': 'C',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B2',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'callSign': 'UAL962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N66057', 'modeS': 'A8B760', 'model': 'Boeing 767-400'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 06:10Z',
#      'local': '2024-11-05 07:10+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:20Z',
#      'local': '2024-11-05 08:20+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:02Z',
#      'local': '2024-11-05 08:02+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABNI', 'modeS': '3C49C9', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-05 04:45Z',
#      'local': '2024-11-05 05:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 04:51Z',
#      'local': '2024-11-05 05:51+01:00'},
#     'runwayTime': {'utc': '2024-11-05 04:57Z',
#      'local': '2024-11-05 05:57+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '002-005',
#     'gate': 'C62',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:30Z',
#      'local': '2024-11-05 08:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:03Z',
#      'local': '2024-11-05 08:03+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 106',
#    'callSign': 'RYR11AM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-LOZ', 'modeS': '4D22B1', 'model': 'Airbus A320'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 06:00Z',
#      'local': '2024-11-05 07:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:00Z',
#      'local': '2024-11-05 07:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:10Z',
#      'local': '2024-11-05 08:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:06Z',
#      'local': '2024-11-05 08:06+01:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'VL 1928',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGP', 'modeS': '3C48F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-05 06:10Z',
#      'local': '2024-11-05 07:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:19Z',
#      'local': '2024-11-05 07:19+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:20Z',
#      'local': '2024-11-05 07:20+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F07',
#     'runway': '16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:25Z',
#      'local': '2024-11-05 08:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:13Z',
#      'local': '2024-11-05 08:13+01:00'},
#     'runwayTime': {'utc': '2024-11-05 07:12Z',
#      'local': '2024-11-05 08:12+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA22N',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LBU', 'modeS': '44006E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-05 06:15Z',
#      'local': '2024-11-05 07:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:15Z',
#      'local': '2024-11-05 07:15+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:38Z',
#      'local': '2024-11-05 07:38+01:00'},
#     'checkInDesk': '1',
#     'gate': 'A53',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:45Z',
#      'local': '2024-11-05 08:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:35Z',
#      'local': '2024-11-05 08:35+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-AAV',
#     'modeS': '502D24',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 07:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 07:45+01:00'},
#     'runwayTime': {'utc': '2024-11-05 07:03Z',
#      'local': '2024-11-05 08:03+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A17',
#     'runway': '07C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:55Z',
#      'local': '2024-11-05 08:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:42Z',
#      'local': '2024-11-05 08:42+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH5CW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUB',
#     'modeS': '3C66A2',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 07:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:53Z',
#      'local': '2024-11-05 07:53+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:53Z',
#      'local': '2024-11-05 07:53+01:00'},
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:04Z',
#      'local': '2024-11-05 09:04+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:03Z',
#      'local': '2024-11-05 09:03+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4075',
#    'callSign': 'EJU93LP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INP', 'modeS': '4402F1', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 07:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:53Z',
#      'local': '2024-11-05 07:53+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:53Z',
#      'local': '2024-11-05 07:53+01:00'},
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:04Z',
#      'local': '2024-11-05 09:04+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:03Z',
#      'local': '2024-11-05 09:03+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4075',
#    'callSign': 'EJU93LP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INP', 'modeS': '4402F1', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-05 06:05Z',
#      'local': '2024-11-05 07:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:55Z',
#      'local': '2024-11-05 07:55+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:55Z',
#      'local': '2024-11-05 08:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR1434',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GUGM', 'modeS': '3950CC', 'model': 'Airbus A318'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 07:00Z',
#      'local': '2024-11-05 08:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:00Z',
#      'local': '2024-11-05 08:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:10Z',
#      'local': '2024-11-05 09:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:09Z',
#      'local': '2024-11-05 09:09+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1930',
#    'callSign': 'DLH2X',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINO',
#     'modeS': '3C65CF',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade',
#      'timeZone': 'Europe/Belgrade'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:40Z',
#      'local': '2024-11-05 08:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:11Z',
#      'local': '2024-11-05 09:11+01:00'},
#     'terminal': '1',
#     'gate': 'Y07',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'JA 354',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YU-APB', 'modeS': '4C01E1', 'model': 'Airbus A319'},
#    'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade',
#      'timeZone': 'Europe/Belgrade'},
#     'scheduledTime': {'utc': '2024-11-05 05:50Z',
#      'local': '2024-11-05 06:50+01:00'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 07:40Z',
#      'local': '2024-11-05 08:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:12Z',
#      'local': '2024-11-05 09:12+01:00'},
#     'terminal': '1',
#     'gate': 'Y07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'JU 354',
#    'callSign': 'ASL37H',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YU-APB', 'modeS': '4C01E1', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2024-11-05 06:20Z',
#      'local': '2024-11-05 06:20+00:00'},
#     'revisedTime': {'utc': '2024-11-05 06:20Z',
#      'local': '2024-11-05 06:20+00:00'},
#     'runwayTime': {'utc': '2024-11-05 06:25Z',
#      'local': '2024-11-05 06:25+00:00'},
#     'terminal': '2',
#     'checkInDesk': '29-56',
#     'gate': '307',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:35Z',
#      'local': '2024-11-05 09:35+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:13Z',
#      'local': '2024-11-05 09:13+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 332',
#    'callSign': 'EIN3JE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-NSC',
#     'modeS': '4CAD7C',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#   {'departure': {'airport': {'icao': 'OJAI',
#      'iata': 'AMM',
#      'name': 'Amman',
#      'timeZone': 'Asia/Amman'},
#     'scheduledTime': {'utc': '2024-11-05 04:18Z',
#      'local': '2024-11-05 07:18+03:00'},
#     'revisedTime': {'utc': '2024-11-05 04:18Z',
#      'local': '2024-11-05 07:18+03:00'},
#     'runwayTime': {'utc': '2024-11-05 04:18Z',
#      'local': '2024-11-05 07:18+03:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#      'local': '2024-11-05 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:16Z',
#      'local': '2024-11-05 09:16+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LY 2371',
#    'callSign': 'ELY2371',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4X-EHF', 'modeS': '738055', 'model': 'Boeing 737'},
#    'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#   {'departure': {'airport': {'icao': 'EIDW',
#      'iata': 'DUB',
#      'name': 'Dublin',
#      'timeZone': 'Europe/Dublin'},
#     'scheduledTime': {'utc': '2024-11-05 06:15Z',
#      'local': '2024-11-05 06:15+00:00'},
#     'revisedTime': {'utc': '2024-11-05 06:15Z',
#      'local': '2024-11-05 06:15+00:00'},
#     'runwayTime': {'utc': '2024-11-05 06:27Z',
#      'local': '2024-11-05 06:27+00:00'},
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '102',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:17Z',
#      'local': '2024-11-05 09:17+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'callSign': 'RYR68RF',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EPC', 'modeS': '4CA911', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-05 07:05Z',
#      'local': '2024-11-05 08:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:20Z',
#      'local': '2024-11-05 08:20+01:00'},
#     'runwayTime': {'utc': '2024-11-05 07:31Z',
#      'local': '2024-11-05 08:31+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'C9',
#     'runway': '24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:21Z',
#      'local': '2024-11-05 09:21+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1771',
#    'callSign': 'KLM1771',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXO', 'modeS': '48418A', 'model': 'Boeing 737'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'name': 'Chisinau'}, 'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#      'local': '2024-11-05 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': '5F 611',
#    'callSign': 'FIA611',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YR-FIC',
#     'modeS': '4A1923',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Fly One', 'iata': '5F', 'icao': 'FIA'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-11-05 07:30Z',
#      'local': '2024-11-05 08:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:40Z',
#      'local': '2024-11-05 08:40+01:00'},
#     'runwayTime': {'utc': '2024-11-05 07:49Z',
#      'local': '2024-11-05 08:49+01:00'},
#     'terminal': 'erminal3',
#     'gate': 'B8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#      'local': '2024-11-05 09:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:27Z',
#      'local': '2024-11-05 09:27+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 1673',
#    'callSign': 'SAS1673',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-ROD',
#     'modeS': '4AC9E4',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-05 06:15Z',
#      'local': '2024-11-05 07:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 06:18Z',
#      'local': '2024-11-05 07:18+01:00'},
#     'runwayTime': {'utc': '2024-11-05 06:31Z',
#      'local': '2024-11-05 07:31+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'B24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:00Z',
#      'local': '2024-11-05 10:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:32Z',
#      'local': '2024-11-05 09:32+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:32Z',
#      'local': '2024-11-05 09:32+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C3',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1882',
#    'callSign': 'VLG1882',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NYF',
#     'modeS': '34744D',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:50Z',
#      'local': '2024-11-05 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:34Z',
#      'local': '2024-11-05 09:34+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:33Z',
#      'local': '2024-11-05 09:33+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1721',
#    'callSign': 'THY4CM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JNL', 'modeS': '4BA9CC', 'model': 'Airbus A330'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'UBBB',
#      'iata': 'GYD',
#      'name': 'Baku',
#      'timeZone': 'Asia/Baku'},
#     'scheduledTime': {'utc': '2024-11-05 03:30Z',
#      'local': '2024-11-05 07:30+04:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:45Z',
#      'local': '2024-11-05 09:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:36Z',
#      'local': '2024-11-05 09:36+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:36Z',
#      'local': '2024-11-05 09:36+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'B2',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'J2 63',
#    'callSign': 'AHY063',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LY-JAM', 'modeS': '503D79', 'model': 'Airbus A320'},
#    'airline': {'name': 'AZAL Azerbaijan', 'iata': 'J2', 'icao': 'AHY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 07:45Z',
#      'local': '2024-11-05 08:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:45Z',
#      'local': '2024-11-05 08:45+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:01Z',
#      'local': '2024-11-05 09:01+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A25',
#     'runway': '07C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:55Z',
#      'local': '2024-11-05 09:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:40Z',
#      'local': '2024-11-05 09:40+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:40Z',
#      'local': '2024-11-05 09:40+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 176',
#    'callSign': 'DLH9KK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISG', 'modeS': '3C6667', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-05 07:05Z',
#      'local': '2024-11-05 07:05+00:00'},
#     'revisedTime': {'utc': '2024-11-05 07:20Z',
#      'local': '2024-11-05 07:20+00:00'},
#     'runwayTime': {'utc': '2024-11-05 07:21Z',
#      'local': '2024-11-05 07:21+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:00Z',
#      'local': '2024-11-05 10:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:43Z',
#      'local': '2024-11-05 09:43+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:42Z',
#      'local': '2024-11-05 09:42+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 990',
#    'callSign': 'BAW990G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUUP', 'modeS': '400A25', 'model': 'Airbus A320'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 07:50Z',
#      'local': '2024-11-05 08:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:50Z',
#      'local': '2024-11-05 08:50+01:00'},
#     'terminal': '3',
#     'gate': '316',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:05Z',
#      'local': '2024-11-05 10:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:51Z',
#      'local': '2024-11-05 09:51+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-05 07:30Z',
#      'local': '2024-11-05 08:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 07:45Z',
#      'local': '2024-11-05 08:45+01:00'},
#     'runwayTime': {'utc': '2024-11-05 07:56Z',
#      'local': '2024-11-05 08:56+01:00'},
#     'checkInDesk': '1',
#     'gate': 'A72',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:55Z',
#      'local': '2024-11-05 09:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:57Z',
#      'local': '2024-11-05 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 976',
#    'callSign': 'SWR2HD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JVY', 'modeS': '4B19FE', 'model': 'Embraer 190'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Düsseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 07:35Z',
#      'local': '2024-11-05 08:35+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:02Z',
#      'local': '2024-11-05 09:02+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:12Z',
#      'local': '2024-11-05 09:12+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:45Z',
#      'local': '2024-11-05 09:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:58Z',
#      'local': '2024-11-05 09:58+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8041',
#    'callSign': 'GWI2R',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 08:00Z',
#      'local': '2024-11-05 09:00+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:00Z',
#      'local': '2024-11-05 09:00+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:22Z',
#      'local': '2024-11-05 09:22+01:00'},
#     'terminal': '2',
#     'runway': '08L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:10Z',
#      'local': '2024-11-05 10:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:06Z',
#      'local': '2024-11-05 10:06+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:05Z',
#      'local': '2024-11-05 10:05+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1934',
#    'callSign': 'DLH5T',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDC', 'modeS': '3C6483', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:10Z',
#      'local': '2024-11-05 09:10+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A75',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 10:09+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 4406',
#    'callSign': 'EWG44U',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:05Z',
#      'local': '2024-11-05 09:05+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:10Z',
#      'local': '2024-11-05 09:10+01:00'},
#     'checkInDesk': '2(5)',
#     'gate': 'A75',
#     'runway': '28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 10:09+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 10:09+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8761',
#    'callSign': 'EWG44U',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-05 07:25Z',
#      'local': '2024-11-05 07:25+00:00'},
#     'revisedTime': {'utc': '2024-11-05 07:37Z',
#      'local': '2024-11-05 07:37+00:00'},
#     'runwayTime': {'utc': '2024-11-05 07:52Z',
#      'local': '2024-11-05 07:52+00:00'},
#     'terminal': '1',
#     'gate': '48',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:05Z',
#      'local': '2024-11-05 10:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:14Z',
#      'local': '2024-11-05 10:14+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:14Z',
#      'local': '2024-11-05 10:14+01:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C1',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 145',
#    'callSign': 'RYR4DA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUH', 'modeS': '4D2347', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-05 08:20Z',
#      'local': '2024-11-05 09:20+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:26Z',
#      'local': '2024-11-05 09:26+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:26Z',
#      'local': '2024-11-05 09:26+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F65',
#     'runway': '16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:35Z',
#      'local': '2024-11-05 10:35+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:19Z',
#      'local': '2024-11-05 10:19+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:18Z',
#      'local': '2024-11-05 10:18+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 225',
#    'callSign': 'AUA225S',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LBY', 'modeS': '4408DE', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 08:50Z',
#      'local': '2024-11-05 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:21Z',
# ...
#     'runwayTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:25Z',
#      'local': '2024-11-05 11:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:01Z',
#      'local': '2024-11-05 11:01+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5082',
#    'callSign': 'EJU86JP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-05 08:10Z',
#      'local': '2024-11-05 09:10+01:00'},
#     'revisedTime': {'utc': '2024-11-05 08:10Z',
#      'local': '2024-11-05 09:10+01:00'},
#     'runwayTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:25Z',
#      'local': '2024-11-05 11:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:01Z',
#      'local': '2024-11-05 11:01+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5082',
#    'callSign': 'EJU86JP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EPWA',
#      'iata': 'WAW',
#      'name': 'Warsaw',
#      'timeZone': 'Europe/Warsaw'},
#     'scheduledTime': {'utc': '2024-11-05 08:25Z',
#      'local': '2024-11-05 09:25+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:07Z',
#      'local': '2024-11-05 10:07+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 10:09+01:00'},
#     'runway': '33',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:03Z',
#      'local': '2024-11-05 11:03+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 387',
#    'callSign': 'LOT7AE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-LNQ', 'modeS': '48ADB9', 'model': 'Embraer 195'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'departure': {'airport': {'icao': 'LGAV',
#      'iata': 'ATH',
#      'name': 'Athens',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2024-11-05 06:50Z',
#      'local': '2024-11-05 08:50+02:00'},
#     'revisedTime': {'utc': '2024-11-05 07:30Z',
#      'local': '2024-11-05 09:30+02:00'},
#     'runwayTime': {'utc': '2024-11-05 07:30Z',
#      'local': '2024-11-05 09:30+02:00'},
#     'terminal': 'D',
#     'checkInDesk': '148--153',
#     'gate': 'B26',
#     'runway': '03R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:05Z',
#      'local': '2024-11-05 11:05+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 820',
#    'callSign': 'AEE8RB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SX-DGA', 'modeS': '4690E1', 'model': 'Airbus A321'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels',
#      'timeZone': 'Europe/Brussels'},
#     'scheduledTime': {'utc': '2024-11-05 08:40Z',
#      'local': '2024-11-05 09:40+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 10:09+01:00'},
#     'checkInDesk': '05',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:05Z',
#      'local': '2024-11-05 11:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:07Z',
#      'local': '2024-11-05 11:07+01:00'},
#     'runwayTime': {'utc': '2024-11-05 11:07Z',
#      'local': '2024-11-05 12:07+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2581',
#    'callSign': 'BEL4NK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNN', 'modeS': '44CDCE', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-05 06:50Z',
#      'local': '2024-11-05 09:50+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:50Z',
#      'local': '2024-11-05 10:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:10Z',
#      'local': '2024-11-05 11:10+01:00'},
#     'runwayTime': {'utc': '2024-11-05 11:20Z',
#      'local': '2024-11-05 12:20+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 977',
#    'callSign': 'PGT5FR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-RBC',
#     'modeS': '4BC843',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-05 08:50Z',
#      'local': '2024-11-05 09:50+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:02Z',
#      'local': '2024-11-05 10:02+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:18Z',
#      'local': '2024-11-05 10:18+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'C11',
#     'runway': '18L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:05Z',
#      'local': '2024-11-05 11:05+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:12Z',
#      'local': '2024-11-05 11:12+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1775',
#    'callSign': 'KLM1775',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BGI', 'modeS': '484B90', 'model': 'Boeing 737'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 09:05Z',
#      'local': '2024-11-05 10:05+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:15Z',
#      'local': '2024-11-05 11:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:15Z',
#      'local': '2024-11-05 11:15+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8051',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AKNV', 'modeS': '3C6DD6', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 09:45+03:00'},
#     'revisedTime': {'utc': '2024-11-05 06:45Z',
#      'local': '2024-11-05 09:45+03:00'},
#     'terminal': '1',
#     'checkInDesk': '104-106',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:20Z',
#      'local': '2024-11-05 11:20+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:17Z',
#      'local': '2024-11-05 11:17+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5007',
#    'callSign': 'PGT92LN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NBD',
#     'modeS': '4BB844',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'GMMX',
#      'iata': 'RAK',
#      'name': 'Marrakech',
#      'timeZone': 'Africa/Casablanca'},
#     'scheduledTime': {'utc': '2024-11-05 06:25Z',
#      'local': '2024-11-05 07:25+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:35Z',
#      'local': '2024-11-05 11:35+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:17Z',
#      'local': '2024-11-05 11:17+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 5475',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IHX',
#     'modeS': '4CAE4A',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 08:45Z',
#      'local': '2024-11-05 09:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:00Z',
#      'local': '2024-11-05 10:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A14',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 09:55Z',
#      'local': '2024-11-05 10:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:27Z',
#      'local': '2024-11-05 11:27+01:00'},
#     'runwayTime': {'utc': '2024-11-05 10:27Z',
#      'local': '2024-11-05 11:27+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B3',
#     'runway': '07L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 178',
#    'callSign': 'DLH178',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIWI', 'modeS': '3C66E9', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-05 08:35Z',
#      'local': '2024-11-05 09:35+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:21Z',
#      'local': '2024-11-05 10:21+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:21Z',
#      'local': '2024-11-05 10:21+01:00'},
#     'terminal': '2F',
#     'runway': '08L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:20Z',
#      'local': '2024-11-05 11:20+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:30Z',
#      'local': '2024-11-05 11:30+01:00'},
#     'runwayTime': {'utc': '2024-11-05 10:29Z',
#      'local': '2024-11-05 11:29+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1734',
#    'callSign': 'AFR66CF',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAJ', 'modeS': '394C09', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 10:55Z',
#      'local': '2024-11-05 11:55+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:52Z',
#      'local': '2024-11-05 11:52+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 180',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZF', 'modeS': '3C6746', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-11-05 09:15Z',
#      'local': '2024-11-05 11:15+02:00'},
#     'revisedTime': {'utc': '2024-11-05 09:09Z',
#      'local': '2024-11-05 11:09+02:00'},
#     'runwayTime': {'utc': '2024-11-05 09:18Z',
#      'local': '2024-11-05 11:18+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '24',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#      'local': '2024-11-05 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:54Z',
#      'local': '2024-11-05 11:54+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1433',
#    'callSign': 'FIN50M',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKL', 'modeS': '461E1B', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-05 09:30Z',
#      'local': '2024-11-05 10:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#      'local': '2024-11-05 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:57Z',
#      'local': '2024-11-05 11:57+01:00'},
#     'runwayTime': {'utc': '2024-11-05 10:56Z',
#      'local': '2024-11-05 11:56+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5064',
#    'callSign': 'EJU89UC',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVK', 'modeS': '440CFE', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-05 09:30Z',
#      'local': '2024-11-05 10:30+01:00'},
#     'revisedTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'runwayTime': {'utc': '2024-11-05 09:45Z',
#      'local': '2024-11-05 10:45+01:00'},
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#      'local': '2024-11-05 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-05 10:57Z',
#      'local': '2024-11-05 11:57+01:00'},
#     'runwayTime': {'utc': '2024-11-05 10:56Z',
#      'local': '2024-11-05 11:56+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5064',
#    'callSign': 'EJU89UC',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVK', 'modeS': '440CFE', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}]}

# %% [markdown]
# # Exploring the json

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 04:30Z',
#     'local': '2024-11-05 05:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 04:30Z',
#     'local': '2024-11-05 05:30+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'DJ 6228',
#   'callSign': 'SRR6228',
#   'status': 'Approaching',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#   'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}},
#  {'departure': {'airport': {'icao': 'OTHH',
#     'iata': 'DOH',
#     'name': 'Doha',
#     'timeZone': 'Asia/Qatar'},
#    'scheduledTime': {'utc': '2024-11-04 23:40Z',
#     'local': '2024-11-05 02:40+03:00'},
#    'revisedTime': {'utc': '2024-11-04 23:39Z',
#     'local': '2024-11-05 02:39+03:00'},
#    'runwayTime': {'utc': '2024-11-04 23:53Z',
#     'local': '2024-11-05 02:53+03:00'},
#    'gate': 'C41',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 05:55Z',
#     'local': '2024-11-05 06:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:39Z',
#     'local': '2024-11-05 06:39+01:00'},
#    'runwayTime': {'utc': '2024-11-05 05:38Z',
#     'local': '2024-11-05 06:38+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A2',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'callSign': 'QTR55H',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'A7-BHG', 'modeS': '06A2EA', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 06:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:11Z',
#     'local': '2024-11-05 06:11+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '78',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#     'local': '2024-11-05 07:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:12Z',
#     'local': '2024-11-05 07:12+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:11Z',
#     'local': '2024-11-05 07:11+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A1',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 1185',
#   'callSign': 'EZS53DP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JXU',
#    'modeS': '4B1A2E',
#    'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 06:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:11Z',
#     'local': '2024-11-05 06:11+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '78',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#     'local': '2024-11-05 07:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:12Z',
#     'local': '2024-11-05 07:12+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:11Z',
#     'local': '2024-11-05 07:11+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A1',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'DS 1185',
#   'callSign': 'EZS53DP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JXU',
#    'modeS': '4B1A2E',
#    'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 05:30Z',
#     'local': '2024-11-05 06:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:30Z',
#     'local': '2024-11-05 06:30+01:00'},
#    'terminal': '3',
#    'gate': '321',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 07:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:20Z',
#     'local': '2024-11-05 07:20+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2000',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 05:30Z',
#     'local': '2024-11-05 06:30+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:40Z',
#     'local': '2024-11-05 07:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:25Z',
#     'local': '2024-11-05 07:25+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AKNV', 'modeS': '3C6DD6', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Düsseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 05:40Z',
#     'local': '2024-11-05 06:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:38Z',
#     'local': '2024-11-05 06:38+01:00'},
#    'runwayTime': {'utc': '2024-11-05 05:45Z',
#     'local': '2024-11-05 06:45+01:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#     'local': '2024-11-05 07:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:30Z',
#     'local': '2024-11-05 07:30+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 9040',
#   'callSign': 'GWI6LZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EWD', 'modeS': '4D2416', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-11-05 05:15Z',
#     'local': '2024-11-05 06:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:09Z',
#     'local': '2024-11-05 06:09+01:00'},
#    'runwayTime': {'utc': '2024-11-05 05:19Z',
#     'local': '2024-11-05 06:19+01:00'},
#    'terminal': '5',
#    'checkInDesk': '22-24',
#    'gate': 'C37',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#     'local': '2024-11-05 07:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:35Z',
#     'local': '2024-11-05 07:35+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5344',
#   'callSign': 'EWG6CA',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EWE', 'modeS': '4D2417', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-11-05 05:15Z',
#     'local': '2024-11-05 06:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:09Z',
#     'local': '2024-11-05 06:09+01:00'},
#    'runwayTime': {'utc': '2024-11-05 05:19Z',
#     'local': '2024-11-05 06:19+01:00'},
#    'terminal': '5',
#    'checkInDesk': '22-24',
#    'gate': 'C37',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:50Z',
#     'local': '2024-11-05 07:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:35Z',
#     'local': '2024-11-05 07:35+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 4600',
#   'callSign': 'EWG6CA',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EWE', 'modeS': '4D2417', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 05:45Z',
#     'local': '2024-11-05 06:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 05:45Z',
#     'local': '2024-11-05 06:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A13',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:37Z',
#     'local': '2024-11-05 07:37+01:00'},
#    'terminal': '1',
#    'gate': 'B02',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AISK', 'modeS': '3C666B', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-11-05 05:05Z',
#     'local': '2024-11-05 07:05+02:00'},
#    'revisedTime': {'utc': '2024-11-05 05:04Z',
#     'local': '2024-11-05 07:04+02:00'},
#    'runwayTime': {'utc': '2024-11-05 05:15Z',
#     'local': '2024-11-05 07:15+02:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '36A',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:00Z',
#     'local': '2024-11-05 08:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:49Z',
#     'local': '2024-11-05 07:49+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:49Z',
#     'local': '2024-11-05 07:49+01:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1431',
#   'callSign': 'FIN3AW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LXI', 'modeS': '461F6A', 'model': 'Airbus A320'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'revisedTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'terminal': 'C',
#    'gate': 'C2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:52Z',
#     'local': '2024-11-05 07:52+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'JU 7659',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSG', 'modeS': '502CD0', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'JU'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'revisedTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'terminal': 'C',
#    'gate': 'C2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:52Z',
#     'local': '2024-11-05 07:52+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:51Z',
#     'local': '2024-11-05 07:51+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'B3',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'BT 211',
#   'callSign': 'BTI74A',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSG', 'modeS': '502CD0', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#  {'departure': {'airport': {'icao': 'EVRA',
#     'iata': 'RIX',
#     'name': 'Riga',
#     'timeZone': 'Europe/Riga'},
#    'scheduledTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'revisedTime': {'utc': '2024-11-05 05:10Z',
#     'local': '2024-11-05 07:10+02:00'},
#    'terminal': 'C',
#    'gate': 'C2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:52Z',
#     'local': '2024-11-05 07:52+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'A3 3219',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSG', 'modeS': '502CD0', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 05:30Z',
#     'local': '2024-11-05 06:30+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:05Z',
#     'local': '2024-11-05 08:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:54Z',
#     'local': '2024-11-05 07:54+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'DX 121',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#   'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#  {'departure': {'airport': {'icao': 'KEWR',
#     'iata': 'EWR',
#     'name': 'Newark',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-11-04 22:50Z',
#     'local': '2024-11-04 17:50-05:00'},
#    'revisedTime': {'utc': '2024-11-04 23:25Z',
#     'local': '2024-11-04 18:25-05:00'},
#    'runwayTime': {'utc': '2024-11-04 23:25Z',
#     'local': '2024-11-04 18:25-05:00'},
#    'terminal': 'C',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B2',
#    'runway': '07L',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'callSign': 'UAL962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N66057', 'modeS': 'A8B760', 'model': 'Boeing 767-400'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 06:10Z',
#     'local': '2024-11-05 07:10+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:20Z',
#     'local': '2024-11-05 08:20+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:02Z',
#     'local': '2024-11-05 08:02+01:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 4',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABNI', 'modeS': '3C49C9', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LEPA',
#     'iata': 'PMI',
#     'name': 'Palma De Mallorca',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-05 04:45Z',
#     'local': '2024-11-05 05:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 04:51Z',
#     'local': '2024-11-05 05:51+01:00'},
#    'runwayTime': {'utc': '2024-11-05 04:57Z',
#     'local': '2024-11-05 05:57+01:00'},
#    'terminal': 'N',
#    'checkInDesk': '002-005',
#    'gate': 'C62',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:30Z',
#     'local': '2024-11-05 08:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:03Z',
#     'local': '2024-11-05 08:03+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 106',
#   'callSign': 'RYR11AM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-LOZ', 'modeS': '4D22B1', 'model': 'Airbus A320'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 06:00Z',
#     'local': '2024-11-05 07:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:00Z',
#     'local': '2024-11-05 07:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:10Z',
#     'local': '2024-11-05 08:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:06Z',
#     'local': '2024-11-05 08:06+01:00'},
#    'terminal': '1',
#    'gate': 'B03',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'VL 1928',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGP', 'modeS': '3C48F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-11-05 06:10Z',
#     'local': '2024-11-05 07:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:19Z',
#     'local': '2024-11-05 07:19+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:20Z',
#     'local': '2024-11-05 07:20+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F07',
#    'runway': '16',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:25Z',
#     'local': '2024-11-05 08:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:13Z',
#     'local': '2024-11-05 08:13+01:00'},
#    'runwayTime': {'utc': '2024-11-05 07:12Z',
#     'local': '2024-11-05 08:12+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 223',
#   'callSign': 'AUA22N',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LBU', 'modeS': '44006E', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-05 06:15Z',
#     'local': '2024-11-05 07:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:15Z',
#     'local': '2024-11-05 07:15+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:38Z',
#     'local': '2024-11-05 07:38+01:00'},
#    'checkInDesk': '1',
#    'gate': 'A53',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:45Z',
#     'local': '2024-11-05 08:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:35Z',
#     'local': '2024-11-05 08:35+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 974',
#   'callSign': 'SWR97Y',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-AAV', 'modeS': '502D24', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 07:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 07:45+01:00'},
#    'runwayTime': {'utc': '2024-11-05 07:03Z',
#     'local': '2024-11-05 08:03+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A17',
#    'runway': '07C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:55Z',
#     'local': '2024-11-05 08:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:42Z',
#     'local': '2024-11-05 08:42+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 174',
#   'callSign': 'DLH5CW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIUB',
#    'modeS': '3C66A2',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 07:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:53Z',
#     'local': '2024-11-05 07:53+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:53Z',
#     'local': '2024-11-05 07:53+01:00'},
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:04Z',
#     'local': '2024-11-05 09:04+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:03Z',
#     'local': '2024-11-05 09:03+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4075',
#   'callSign': 'EJU93LP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INP', 'modeS': '4402F1', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 07:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:53Z',
#     'local': '2024-11-05 07:53+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:53Z',
#     'local': '2024-11-05 07:53+01:00'},
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:04Z',
#     'local': '2024-11-05 09:04+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:03Z',
#     'local': '2024-11-05 09:03+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4075',
#   'callSign': 'EJU93LP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INP', 'modeS': '4402F1', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-11-05 06:05Z',
#     'local': '2024-11-05 07:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:55Z',
#     'local': '2024-11-05 07:55+01:00'},
#    'terminal': '2F',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:55Z',
#     'local': '2024-11-05 08:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1434',
#   'callSign': 'AFR1434',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-GUGM', 'modeS': '3950CC', 'model': 'Airbus A318'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 07:00Z',
#     'local': '2024-11-05 08:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:00Z',
#     'local': '2024-11-05 08:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:09Z',
#     'local': '2024-11-05 09:09+01:00'},
#    'terminal': '1',
#    'gate': 'B02',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1930',
#   'callSign': 'DLH2X',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AINO',
#    'modeS': '3C65CF',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LYBE',
#     'iata': 'BEG',
#     'name': 'Belgrade',
#     'timeZone': 'Europe/Belgrade'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:40Z',
#     'local': '2024-11-05 08:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:11Z',
#     'local': '2024-11-05 09:11+01:00'},
#    'terminal': '1',
#    'gate': 'Y07',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'JA 354',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YU-APB', 'modeS': '4C01E1', 'model': 'Airbus A319'},
#   'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#  {'departure': {'airport': {'icao': 'LYBE',
#     'iata': 'BEG',
#     'name': 'Belgrade',
#     'timeZone': 'Europe/Belgrade'},
#    'scheduledTime': {'utc': '2024-11-05 05:50Z',
#     'local': '2024-11-05 06:50+01:00'},
#    'terminal': '2',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 07:40Z',
#     'local': '2024-11-05 08:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:12Z',
#     'local': '2024-11-05 09:12+01:00'},
#    'terminal': '1',
#    'gate': 'Y07',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'JU 354',
#   'callSign': 'ASL37H',
#   'status': 'Delayed',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YU-APB', 'modeS': '4C01E1', 'model': 'Airbus A319'},
#   'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#  {'departure': {'airport': {'icao': 'EIDW',
#     'iata': 'DUB',
#     'name': 'Dublin',
#     'timeZone': 'Europe/Dublin'},
#    'scheduledTime': {'utc': '2024-11-05 06:20Z',
#     'local': '2024-11-05 06:20+00:00'},
#    'revisedTime': {'utc': '2024-11-05 06:20Z',
#     'local': '2024-11-05 06:20+00:00'},
#    'runwayTime': {'utc': '2024-11-05 06:25Z',
#     'local': '2024-11-05 06:25+00:00'},
#    'terminal': '2',
#    'checkInDesk': '29-56',
#    'gate': '307',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:35Z',
#     'local': '2024-11-05 09:35+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:13Z',
#     'local': '2024-11-05 09:13+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EI 332',
#   'callSign': 'EIN3JE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-NSC', 'modeS': '4CAD7C', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#  {'departure': {'airport': {'icao': 'OJAI',
#     'iata': 'AMM',
#     'name': 'Amman',
#     'timeZone': 'Asia/Amman'},
#    'scheduledTime': {'utc': '2024-11-05 04:18Z',
#     'local': '2024-11-05 07:18+03:00'},
#    'revisedTime': {'utc': '2024-11-05 04:18Z',
#     'local': '2024-11-05 07:18+03:00'},
#    'runwayTime': {'utc': '2024-11-05 04:18Z',
#     'local': '2024-11-05 07:18+03:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#     'local': '2024-11-05 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:16Z',
#     'local': '2024-11-05 09:16+01:00'},
#    'terminal': '1',
#    'gate': 'X19',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LY 2371',
#   'callSign': 'ELY2371',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '4X-EHF', 'modeS': '738055', 'model': 'Boeing 737'},
#   'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#  {'departure': {'airport': {'icao': 'EIDW',
#     'iata': 'DUB',
#     'name': 'Dublin',
#     'timeZone': 'Europe/Dublin'},
#    'scheduledTime': {'utc': '2024-11-05 06:15Z',
#     'local': '2024-11-05 06:15+00:00'},
#    'revisedTime': {'utc': '2024-11-05 06:15Z',
#     'local': '2024-11-05 06:15+00:00'},
#    'runwayTime': {'utc': '2024-11-05 06:27Z',
#     'local': '2024-11-05 06:27+00:00'},
#    'terminal': '1',
#    'checkInDesk': '1204-1319',
#    'gate': '102',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:17Z',
#     'local': '2024-11-05 09:17+01:00'},
#    'terminal': '2',
#    'gate': 'Z42',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3669',
#   'callSign': 'RYR68RF',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EPC', 'modeS': '4CA911', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-11-05 07:05Z',
#     'local': '2024-11-05 08:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:20Z',
#     'local': '2024-11-05 08:20+01:00'},
#    'runwayTime': {'utc': '2024-11-05 07:31Z',
#     'local': '2024-11-05 08:31+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'C9',
#    'runway': '24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:21Z',
#     'local': '2024-11-05 09:21+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1771',
#   'callSign': 'KLM1771',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BXO', 'modeS': '48418A', 'model': 'Boeing 737'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'name': 'Chisinau'}, 'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#     'local': '2024-11-05 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': '5F 611',
#   'callSign': 'FIA611',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YR-FIC',
#    'modeS': '4A1923',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Fly One', 'iata': '5F', 'icao': 'FIA'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-11-05 07:30Z',
#     'local': '2024-11-05 08:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:40Z',
#     'local': '2024-11-05 08:40+01:00'},
#    'runwayTime': {'utc': '2024-11-05 07:49Z',
#     'local': '2024-11-05 08:49+01:00'},
#    'terminal': 'erminal3',
#    'gate': 'B8',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:30Z',
#     'local': '2024-11-05 09:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:27Z',
#     'local': '2024-11-05 09:27+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'SK 1673',
#   'callSign': 'SAS1673',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-ROD',
#    'modeS': '4AC9E4',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-05 06:15Z',
#     'local': '2024-11-05 07:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:18Z',
#     'local': '2024-11-05 07:18+01:00'},
#    'runwayTime': {'utc': '2024-11-05 06:31Z',
#     'local': '2024-11-05 07:31+01:00'},
#    'terminal': '1',
#    'checkInDesk': '501-514',
#    'gate': 'B24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:00Z',
#     'local': '2024-11-05 10:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:32Z',
#     'local': '2024-11-05 09:32+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:32Z',
#     'local': '2024-11-05 09:32+01:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C3',
#    'runway': '07L',
#    'quality': ['Basic', 'Live']},
#   'number': 'VY 1882',
#   'callSign': 'VLG1882',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-NYF', 'modeS': '34744D', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:50Z',
#     'local': '2024-11-05 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:34Z',
#     'local': '2024-11-05 09:34+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:33Z',
#     'local': '2024-11-05 09:33+01:00'},
#    'terminal': '1',
#    'gate': 'X03',
#    'baggageBelt': 'A3',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1721',
#   'callSign': 'THY4CM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-JNL', 'modeS': '4BA9CC', 'model': 'Airbus A330'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'UBBB',
#     'iata': 'GYD',
#     'name': 'Baku',
#     'timeZone': 'Asia/Baku'},
#    'scheduledTime': {'utc': '2024-11-05 03:30Z',
#     'local': '2024-11-05 07:30+04:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:45Z',
#     'local': '2024-11-05 09:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:36Z',
#     'local': '2024-11-05 09:36+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:36Z',
#     'local': '2024-11-05 09:36+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'B2',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'J2 63',
#   'callSign': 'AHY063',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LY-JAM', 'modeS': '503D79', 'model': 'Airbus A320'},
#   'airline': {'name': 'AZAL Azerbaijan', 'iata': 'J2', 'icao': 'AHY'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 07:45Z',
#     'local': '2024-11-05 08:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:45Z',
#     'local': '2024-11-05 08:45+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:01Z',
#     'local': '2024-11-05 09:01+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A25',
#    'runway': '07C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:55Z',
#     'local': '2024-11-05 09:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:40Z',
#     'local': '2024-11-05 09:40+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:40Z',
#     'local': '2024-11-05 09:40+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 176',
#   'callSign': 'DLH9KK',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AISG', 'modeS': '3C6667', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-05 07:05Z',
#     'local': '2024-11-05 07:05+00:00'},
#    'revisedTime': {'utc': '2024-11-05 07:20Z',
#     'local': '2024-11-05 07:20+00:00'},
#    'runwayTime': {'utc': '2024-11-05 07:21Z',
#     'local': '2024-11-05 07:21+00:00'},
#    'terminal': '5',
#    'checkInDesk': 'D',
#    'runway': '27L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:00Z',
#     'local': '2024-11-05 10:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:43Z',
#     'local': '2024-11-05 09:43+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:42Z',
#     'local': '2024-11-05 09:42+01:00'},
#    'terminal': '1',
#    'gate': 'Y03',
#    'baggageBelt': 'B1',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 990',
#   'callSign': 'BAW990G',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EUUP', 'modeS': '400A25', 'model': 'Airbus A320'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 07:50Z',
#     'local': '2024-11-05 08:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:50Z',
#     'local': '2024-11-05 08:50+01:00'},
#    'terminal': '3',
#    'gate': '316',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:05Z',
#     'local': '2024-11-05 10:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:51Z',
#     'local': '2024-11-05 09:51+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8001',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-05 07:30Z',
#     'local': '2024-11-05 08:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 07:45Z',
#     'local': '2024-11-05 08:45+01:00'},
#    'runwayTime': {'utc': '2024-11-05 07:56Z',
#     'local': '2024-11-05 08:56+01:00'},
#    'checkInDesk': '1',
#    'gate': 'A72',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:55Z',
#     'local': '2024-11-05 09:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:57Z',
#     'local': '2024-11-05 09:57+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 976',
#   'callSign': 'SWR2HD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JVY', 'modeS': '4B19FE', 'model': 'Embraer 190'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Düsseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 07:35Z',
#     'local': '2024-11-05 08:35+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:02Z',
#     'local': '2024-11-05 09:02+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:12Z',
#     'local': '2024-11-05 09:12+01:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:45Z',
#     'local': '2024-11-05 09:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:58Z',
#     'local': '2024-11-05 09:58+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8041',
#   'callSign': 'GWI2R',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 08:00Z',
#     'local': '2024-11-05 09:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:00Z',
#     'local': '2024-11-05 09:00+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:22Z',
#     'local': '2024-11-05 09:22+01:00'},
#    'terminal': '2',
#    'runway': '08L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:10Z',
#     'local': '2024-11-05 10:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:06Z',
#     'local': '2024-11-05 10:06+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:05Z',
#     'local': '2024-11-05 10:05+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1934',
#   'callSign': 'DLH5T',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIDC', 'modeS': '3C6483', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A75',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 10:09+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 4406',
#   'callSign': 'EWG44U',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:05Z',
#     'local': '2024-11-05 09:05+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'checkInDesk': '2(5)',
#    'gate': 'A75',
#    'runway': '28',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 10:09+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 10:09+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8761',
#   'callSign': 'EWG44U',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWO', 'modeS': '3C56EF', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EGSS',
#     'iata': 'STN',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-11-05 07:25Z',
#     'local': '2024-11-05 07:25+00:00'},
#    'revisedTime': {'utc': '2024-11-05 07:37Z',
#     'local': '2024-11-05 07:37+00:00'},
#    'runwayTime': {'utc': '2024-11-05 07:52Z',
#     'local': '2024-11-05 07:52+00:00'},
#    'terminal': '1',
#    'gate': '48',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:05Z',
#     'local': '2024-11-05 10:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:14Z',
#     'local': '2024-11-05 10:14+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:14Z',
#     'local': '2024-11-05 10:14+01:00'},
#    'terminal': '2',
#    'gate': 'Z38',
#    'baggageBelt': 'C1',
#    'runway': '07L',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 145',
#   'callSign': 'RYR4DA',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VUH', 'modeS': '4D2347', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-11-05 08:20Z',
#     'local': '2024-11-05 09:20+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:26Z',
#     'local': '2024-11-05 09:26+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:26Z',
#     'local': '2024-11-05 09:26+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F65',
#    'runway': '16',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:35Z',
#     'local': '2024-11-05 10:35+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:19Z',
#     'local': '2024-11-05 10:19+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:18Z',
#     'local': '2024-11-05 10:18+01:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 225',
#   'callSign': 'AUA225S',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LBY', 'modeS': '4408DE', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 08:50Z',
#     'local': '2024-11-05 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:21Z',
#     'local': '2024-11-05 10:21+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:50Z',
#     'local': '2024-11-05 09:50+01:00'},
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': '4U 7K',
#   'callSign': 'GWI7K',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'icao': 'LEMG',
#     'iata': 'AGP',
#     'name': 'Málaga',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-11-05 06:30Z',
#     'local': '2024-11-05 07:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 06:30Z',
#     'local': '2024-11-05 07:30+01:00'},
#    'terminal': 'PAX',
#    'checkInDesk': '363-370',
#    'gate': 'C35',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:00Z',
#     'local': '2024-11-05 11:00+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:32Z',
#     'local': '2024-11-05 10:32+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 233',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-IHW',
#    'modeS': '4CAE49',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
# ...
#   'isCargo': False,
#   'aircraft': {'reg': 'G-LCYN', 'modeS': '4063C3', 'model': 'Embraer 190'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:25Z',
#     'local': '2024-11-05 11:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:01Z',
#     'local': '2024-11-05 11:01+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5082',
#   'callSign': 'EJU86JP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'revisedTime': {'utc': '2024-11-05 08:10Z',
#     'local': '2024-11-05 09:10+01:00'},
#    'runwayTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:25Z',
#     'local': '2024-11-05 11:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:01Z',
#     'local': '2024-11-05 11:01+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5082',
#   'callSign': 'EJU86JP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EPWA',
#     'iata': 'WAW',
#     'name': 'Warsaw',
#     'timeZone': 'Europe/Warsaw'},
#    'scheduledTime': {'utc': '2024-11-05 08:25Z',
#     'local': '2024-11-05 09:25+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:07Z',
#     'local': '2024-11-05 10:07+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 10:09+01:00'},
#    'runway': '33',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:03Z',
#     'local': '2024-11-05 11:03+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LO 387',
#   'callSign': 'LOT7AE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SP-LNQ', 'modeS': '48ADB9', 'model': 'Embraer 195'},
#   'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#  {'departure': {'airport': {'icao': 'LGAV',
#     'iata': 'ATH',
#     'name': 'Athens',
#     'timeZone': 'Europe/Athens'},
#    'scheduledTime': {'utc': '2024-11-05 06:50Z',
#     'local': '2024-11-05 08:50+02:00'},
#    'revisedTime': {'utc': '2024-11-05 07:30Z',
#     'local': '2024-11-05 09:30+02:00'},
#    'runwayTime': {'utc': '2024-11-05 07:30Z',
#     'local': '2024-11-05 09:30+02:00'},
#    'terminal': 'D',
#    'checkInDesk': '148--153',
#    'gate': 'B26',
#    'runway': '03R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:05Z',
#     'local': '2024-11-05 11:05+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'A3 820',
#   'callSign': 'AEE8RB',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SX-DGA', 'modeS': '4690E1', 'model': 'Airbus A321'},
#   'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#  {'departure': {'airport': {'icao': 'EBBR',
#     'iata': 'BRU',
#     'name': 'Brussels',
#     'timeZone': 'Europe/Brussels'},
#    'scheduledTime': {'utc': '2024-11-05 08:40Z',
#     'local': '2024-11-05 09:40+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 10:09+01:00'},
#    'checkInDesk': '05',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:05Z',
#     'local': '2024-11-05 11:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:07Z',
#     'local': '2024-11-05 11:07+01:00'},
#    'runwayTime': {'utc': '2024-11-05 11:07Z',
#     'local': '2024-11-05 12:07+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'SN 2581',
#   'callSign': 'BEL4NK',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OO-SNN', 'modeS': '44CDCE', 'model': 'Airbus A320'},
#   'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#  {'departure': {'airport': {'icao': 'LTFJ',
#     'iata': 'SAW',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-11-05 06:50Z',
#     'local': '2024-11-05 09:50+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:50Z',
#     'local': '2024-11-05 10:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:10Z',
#     'local': '2024-11-05 11:10+01:00'},
#    'runwayTime': {'utc': '2024-11-05 11:20Z',
#     'local': '2024-11-05 12:20+01:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 977',
#   'callSign': 'PGT5FR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-RBC', 'modeS': '4BC843', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-11-05 08:50Z',
#     'local': '2024-11-05 09:50+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:02Z',
#     'local': '2024-11-05 10:02+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:18Z',
#     'local': '2024-11-05 10:18+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'C11',
#    'runway': '18L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:05Z',
#     'local': '2024-11-05 11:05+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:12Z',
#     'local': '2024-11-05 11:12+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1775',
#   'callSign': 'KLM1775',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BGI', 'modeS': '484B90', 'model': 'Boeing 737'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 09:05Z',
#     'local': '2024-11-05 10:05+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:15Z',
#     'local': '2024-11-05 11:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:15Z',
#     'local': '2024-11-05 11:15+01:00'},
#    'terminal': '1',
#    'gate': 'A20',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8051',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AKNV', 'modeS': '3C6DD6', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 09:45+03:00'},
#    'revisedTime': {'utc': '2024-11-05 06:45Z',
#     'local': '2024-11-05 09:45+03:00'},
#    'terminal': '1',
#    'checkInDesk': '104-106',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:20Z',
#     'local': '2024-11-05 11:20+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:17Z',
#     'local': '2024-11-05 11:17+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 5007',
#   'callSign': 'PGT92LN',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-NBD',
#    'modeS': '4BB844',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'GMMX',
#     'iata': 'RAK',
#     'name': 'Marrakech',
#     'timeZone': 'Africa/Casablanca'},
#    'scheduledTime': {'utc': '2024-11-05 06:25Z',
#     'local': '2024-11-05 07:25+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:35Z',
#     'local': '2024-11-05 11:35+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:17Z',
#     'local': '2024-11-05 11:17+01:00'},
#    'terminal': '2',
#    'gate': 'Z40',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 5475',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-IHX',
#    'modeS': '4CAE4A',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 08:45Z',
#     'local': '2024-11-05 09:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:00Z',
#     'local': '2024-11-05 10:00+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A14',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 09:55Z',
#     'local': '2024-11-05 10:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:27Z',
#     'local': '2024-11-05 11:27+01:00'},
#    'runwayTime': {'utc': '2024-11-05 10:27Z',
#     'local': '2024-11-05 11:27+01:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B3',
#    'runway': '07L',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 178',
#   'callSign': 'DLH178',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIWI', 'modeS': '3C66E9', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-11-05 08:35Z',
#     'local': '2024-11-05 09:35+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:21Z',
#     'local': '2024-11-05 10:21+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:21Z',
#     'local': '2024-11-05 10:21+01:00'},
#    'terminal': '2F',
#    'runway': '08L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:20Z',
#     'local': '2024-11-05 11:20+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:30Z',
#     'local': '2024-11-05 11:30+01:00'},
#    'runwayTime': {'utc': '2024-11-05 10:29Z',
#     'local': '2024-11-05 11:29+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1734',
#   'callSign': 'AFR66CF',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-GTAJ', 'modeS': '394C09', 'model': 'Airbus A321'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A13',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 10:55Z',
#     'local': '2024-11-05 11:55+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:52Z',
#     'local': '2024-11-05 11:52+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 180',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIZF', 'modeS': '3C6746', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-11-05 09:15Z',
#     'local': '2024-11-05 11:15+02:00'},
#    'revisedTime': {'utc': '2024-11-05 09:09Z',
#     'local': '2024-11-05 11:09+02:00'},
#    'runwayTime': {'utc': '2024-11-05 09:18Z',
#     'local': '2024-11-05 11:18+02:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '24',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#     'local': '2024-11-05 12:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:54Z',
#     'local': '2024-11-05 11:54+01:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1433',
#   'callSign': 'FIN50M',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LKL', 'modeS': '461E1B', 'model': 'Embraer 190'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 09:30Z',
#     'local': '2024-11-05 10:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'runway': '36',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#     'local': '2024-11-05 12:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:57Z',
#     'local': '2024-11-05 11:57+01:00'},
#    'runwayTime': {'utc': '2024-11-05 10:56Z',
#     'local': '2024-11-05 11:56+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5064',
#   'callSign': 'EJU89UC',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVK', 'modeS': '440CFE', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-11-05 09:30Z',
#     'local': '2024-11-05 10:30+01:00'},
#    'revisedTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'runwayTime': {'utc': '2024-11-05 09:45Z',
#     'local': '2024-11-05 10:45+01:00'},
#    'runway': '36',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-11-05 11:15Z',
#     'local': '2024-11-05 12:15+01:00'},
#    'revisedTime': {'utc': '2024-11-05 10:57Z',
#     'local': '2024-11-05 11:57+01:00'},
#    'runwayTime': {'utc': '2024-11-05 10:56Z',
#     'local': '2024-11-05 11:56+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'runway': '07R',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5064',
#   'callSign': 'EJU89UC',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVK', 'modeS': '440CFE', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}]

# %% [markdown]
# The square brackets at the beginning of `flights_json` indicate that it represents a list-like structure. Since we're dealing with a list, we can iterate through its elements to access and process the data. Let's start by examining the first element in the list.

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'EDDK',
#    'iata': 'CGN',
#    'name': 'Cologne',
#    'timeZone': 'Europe/Berlin'},
#   'quality': []},
#  'arrival': {'scheduledTime': {'utc': '2024-11-05 04:30Z',
#    'local': '2024-11-05 05:30+01:00'},
#   'revisedTime': {'utc': '2024-11-05 04:30Z',
#    'local': '2024-11-05 05:30+01:00'},
#   'quality': ['Basic', 'Live']},
#  'number': 'DJ 6228',
#  'callSign': 'SRR6228',
#  'status': 'Approaching',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'OY-SRM', 'modeS': '45CE4D', 'model': 'Boeing 767'},
#  'airline': {'name': 'Star Air A/S', 'iata': 'DJ', 'icao': 'SRR'}}

# %%
flights_json["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %% [markdown]
# Looking at the first element of the json and the available keys, we can select the information we think would be important for our dataframe.
# - Departure airport icao
# - scheduled arrival time, local
# - flight number

# %% [markdown]
# # Using for loops

# %% [markdown]
# ## Making the DataFrame

# %%
flight_items = []

for item in flights_json["arrivals"]:
  flight_item = {
      "arrival_airport_icao": icao,
      "departure_airport_icao": item["departure"]["airport"].get("icao", None),
      "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
      "flight_number": item.get("number", None)
  }

  flight_items.append(flight_item)

flights_df = pd.DataFrame(flight_items)

flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao  scheduled_arrival_time  \
# 0                 EDDB                   EDDK  2024-11-05 05:30+01:00
# 1                 EDDB                   OTHH  2024-11-05 06:55+01:00
# 2                 EDDB                   LFSB  2024-11-05 07:40+01:00
# 3                 EDDB                   LFSB  2024-11-05 07:40+01:00
# 4                 EDDB                   EDDS  2024-11-05 07:45+01:00
#
#   flight_number
# 0       DJ 6228
# 1         QR 79
# 2       U2 1185
# 3       DS 1185
# 4       EW 2000

# %% [markdown]
# Let's get rid of the `+01:00` from `scheduled_arrival_time`.

# %%
flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                 EDDB                   EDDK       2024-11-05 05:30
# 1                 EDDB                   OTHH       2024-11-05 06:55
# 2                 EDDB                   LFSB       2024-11-05 07:40
# 3                 EDDB                   LFSB       2024-11-05 07:40
# 4                 EDDB                   EDDS       2024-11-05 07:45
#
#   flight_number
# 0       DJ 6228
# 1         QR 79
# 2       U2 1185
# 3       DS 1185
# 4       EW 2000

# %% [markdown]
# While string slicing provides a quick solution to correcting the `scheduled_arrival_time` column, it's not the most robust approach. This is because it assumes that every cell in the column has the `+01:00` time zone offset. If there are cells without this offset, slicing would remove part of the time value, leading to inaccurate results.
#
# A more robust solution would involve using the `re.sub()` function from the re module. Feel free to look into this if you have extra time and are curious.

# %% [markdown]
# ## Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = os.getenv('aerodatabox_api_key')

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': api_key
          }

      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %%
icao_list = ["EDDB", "EDDF"]

get_flight_data(icao_list)
# Out:
#      arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                    EDDB                   ZBAA    2024-11-06 06:40:00
# 1                    EDDB                   OTHH    2024-11-06 06:55:00
# 2                    EDDB                   EDDS    2024-11-06 07:35:00
# 3                    EDDB                   EDDK    2024-11-06 07:40:00
# 4                    EDDB                   KEWR    2024-11-06 07:55:00
# ...                   ...                    ...                    ...
# 2218                 EDDF                   LPPT    2024-11-06 22:40:00
# 2219                 EDDF                   LPPT    2024-11-06 22:40:00
# 2220                 EDDF                   LPPT    2024-11-06 22:40:00
# 2221                 EDDF                   DTTJ    2024-11-06 22:45:00
# 2222                 EDDF                   GCRR    2024-11-06 22:45:00
#
#      flight_number   data_retrieved_at
# 0           HU 489 2024-11-05 16:34:20
# 1            QR 79 2024-11-05 16:34:20
# 2          EW 8001 2024-11-05 16:34:20
# 3             EW 2 2024-11-05 16:34:20
# 4           UA 962 2024-11-05 16:34:20
# ...            ...                 ...
# 2218       LH 6957 2024-11-05 16:34:21
# 2219        TP 574 2024-11-05 16:34:21
# 2220       AC 2660 2024-11-05 16:34:21
# 2221       X3 6573 2024-11-05 16:34:21
# 2222       X3 2187 2024-11-05 16:34:21
#
# [2223 rows x 5 columns]

# %% [markdown]
# Your flight function can now be incorporated with your other functions to send and receive data from your SQL database.

# %% [markdown]
# # Using json_normalize

# %%
def tomorrows_flight_arrivals(icao_list):

    api_key = os.getenv('aerodatabox_api_key')

    berlin_timezone = timezone('Europe/Berlin')
    today = datetime.now(berlin_timezone).date()
    tomorrow = (today + timedelta(days=1))

    list_for_arrivals_df = []

    for icao in icao_list:

        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"direction":"Arrival","withCancelled":"false"}

            headers = {
                "X-RapidAPI-Key": api_key,
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.request("GET", url, headers=headers, params=querystring)
            flights_resp = response.json()

            arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "airline.name", "movement.scheduledTime.local", "movement.terminal", "movement.airport.name", "movement.airport.icao"]]
            arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "airline.name": "airline", "movement.scheduledTime.local": "arrival_time", "movement.terminal": "arrival_terminal", "movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
            arrivals_df["arrival_airport_icao"] = icao
            arrivals_df["data_retrieved_on"] = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")
            arrivals_df = arrivals_df[["arrival_airport_icao", "flight_number", "airline", "arrival_time", "arrival_terminal", "departure_city", "departure_airport_icao", "data_retrieved_on"]]

            # fixing arrival_time
            arrivals_df["arrival_time"] = arrivals_df["arrival_time"].str.split("+").str[0]

            list_for_arrivals_df.append(arrivals_df)

    return pd.concat(list_for_arrivals_df, ignore_index=True)

# %%
icao_list = ["EDDF", "EDDB"]

tomorrows_flight_arrivals(icao_list)
# Out:
#      arrival_airport_icao flight_number            airline      arrival_time  \
# 0                    EDDF        4Y 133  Discover Airlines  2024-11-06 05:20
# 1                    EDDF       OS 8460           Austrian  2024-11-06 05:20
# 2                    EDDF       LX 9309              SWISS  2024-11-06 05:20
# 3                    EDDF       LH 4357          Lufthansa  2024-11-06 05:20
# 4                    EDDF       OS 7316           Austrian  2024-11-06 05:20
# ...                   ...           ...                ...               ...
# 2218                 EDDB       EC 5150     EasyJet Europe  2024-11-06 22:55
# 2219                 EDDB       FR 2419            Ryanair  2024-11-06 22:55
# 2220                 EDDB       IB 1809             Iberia  2024-11-06 23:10
# 2221                 EDDB       I2 1809     Iberia Express  2024-11-06 23:10
# 2222                 EDDB       EW 1151          Eurowings  2024-11-06 23:20
#
#      arrival_terminal   departure_city departure_airport_icao  \
# 0                   1         Windhoek                   FYWH
# 1                   1         Windhoek                   FYWH
# 2                   1         Windhoek                   FYWH
# 3                   1         Windhoek                   FYWH
# 4                   1          Jo'anna                   FAOR
# ...               ...              ...                    ...
# 2218                1            Paris                   LFPG
# 2219                2  Tenerife Island                   GCTS
# 2220                1           Madrid                   LEMD
# 2221                1           Madrid                   LEMD
# 2222                1            Dubai                   OMDB
#
#         data_retrieved_on
# 0     2024-11-05 16:34:21
# 1     2024-11-05 16:34:21
# 2     2024-11-05 16:34:21
# 3     2024-11-05 16:34:21
# 4     2024-11-05 16:34:21
# ...                   ...
# 2218  2024-11-05 16:34:23
# 2219  2024-11-05 16:34:23
# 2220  2024-11-05 16:34:23
# 2221  2024-11-05 16:34:23
# 2222  2024-11-05 16:34:23
#
# [2223 rows x 8 columns]
